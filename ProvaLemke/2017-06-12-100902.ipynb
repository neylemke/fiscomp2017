# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("jogadores.csv")

# %%
df.columns
# Out:
# Index([u'Nome', u'Sobrenome', u'Altura', u'Peso', u'Data Nascimento'], dtype='object')

# %%
sns.lmplot(x = 'Altura', y = 'Peso', data = df, palette="Set2", fit_reg = False)
