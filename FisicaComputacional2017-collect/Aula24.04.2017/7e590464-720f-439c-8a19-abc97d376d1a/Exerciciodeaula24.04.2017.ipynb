# %%
# Exercício 01. Crie 12 arquivos, chamados de 'arq_mes_estação.txt'. Cada um deles contendo a frase: A minha estação predileta é 'estação', especialmente o 'mês' repetida um número aleatório de vezes, entre 5 e 20.


m = ['janeiro', 'fevereiro', 'março', 'abril', 'maio', 'junho', 'julho', 'agosto', 'setembro', 'outubro', 'novembro', 'dezembro']
e = ['outono', 'inverno', 'primavera', 'verão']

from random import randrange
for i in range(1,13):
    if i > 3 and i <= 6:
        j = 1
    elif i >= 6 and i <= 9:
        j = 2
    elif i >= 9 and i <= 12:
        j = 3
    else:
        j = 4
    
    content = "A minha estação predileta é "+str(e[j-1])+", especialmente o "+str(m[j-i])+"mês' repetida um número aleatório de vezes, entre 5 e 20.\n"
    with open('arq_'+str(m[i-1])+'_'+str(e[j-1])+'.txt', 'w') as f:
        for k in range(1,randrange(6,20)):
            f.write(content)
    f.close()
    
    # !zip file.zip arq*.txt
# Out:
#   adding: arq_abril_outono.txt (deflated 84%)
#   adding: arq_agosto_inverno.txt (deflated 93%)
#   adding: arq_dezembro_primavera.txt (deflated 89%)
#   adding: arq_fevereiro_verão.txt (deflated 90%)
#   adding: arq_janeiro_verão.txt (deflated 81%)
#   adding: arq_julho_inverno.txt (deflated 93%)
#   adding: arq_junho_outono.txt (deflated 93%)
#   adding: arq_maio_outono.txt (deflated 84%)
#   adding: arq_março_verão.txt (deflated 93%)
#   adding: arq_novembro_primavera.txt (deflated 92%)
#   adding: arq_outubro_primavera.txt (deflated 94%)
#   adding: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 84%)
# updating: arq_agosto_inverno.txt (deflated 93%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 93%)
# updating: arq_junho_outono.txt (deflated 93%)
# updating: arq_maio_outono.txt (deflated 84%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 84%)
# updating: arq_agosto_inverno.txt (deflated 93%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 93%)
# updating: arq_junho_outono.txt (deflated 93%)
# updating: arq_maio_outono.txt (deflated 84%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 93%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 93%)
# updating: arq_junho_outono.txt (deflated 93%)
# updating: arq_maio_outono.txt (deflated 84%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 93%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 93%)
# updating: arq_junho_outono.txt (deflated 93%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 93%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 93%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 93%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 81%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 84%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 81%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 93%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 84%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 81%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 94%)
# updating: arq_setembro_inverno.txt (deflated 92%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 84%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 81%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 92%)
# updating: arq_outubro_primavera.txt (deflated 86%)
# updating: arq_setembro_inverno.txt (deflated 92%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 84%)
# updating: arq_dezembro_primavera.txt (deflated 89%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 81%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 91%)
# updating: arq_outubro_primavera.txt (deflated 86%)
# updating: arq_setembro_inverno.txt (deflated 92%)
# updating: arq_abril_outono.txt (deflated 86%)
# updating: arq_agosto_inverno.txt (deflated 84%)
# updating: arq_dezembro_primavera.txt (deflated 92%)
# updating: arq_fevereiro_verão.txt (deflated 93%)
# updating: arq_janeiro_verão.txt (deflated 81%)
# updating: arq_julho_inverno.txt (deflated 81%)
# updating: arq_junho_outono.txt (deflated 81%)
# updating: arq_maio_outono.txt (deflated 92%)
# updating: arq_março_verão.txt (deflated 93%)
# updating: arq_novembro_primavera.txt (deflated 91%)
# updating: arq_outubro_primavera.txt (deflated 86%)
# updating: arq_setembro_inverno.txt (deflated 92%)

# %%
# !ls -la > teste.txt

file=open('teste.txt','r')
data=[]
for line in file:
    data=data+[line.split()]
data=data[1:]

import pandas as pd
filedict=[{'perm': list[0],  'group': list[1], 'user': list[2], 'usercode': list[3],
           'filesize': list[4],
  'month': list[5], 'day': list[6], 'hour': list[7], 'filename':list[8]} for list in data]
df=pd.DataFrame(filedict)

mday = df['day'].min()
df[df['day']==mday]


#(df.ix[2])
# Out:
#    day                                 filename filesize group   hour month  \
# 2   23         .Analisedados.ipynb.sage-jupyter     7131     1  16:59   Apr
# 16  23       .Aula24.03.2017.ipynb.sage-jupyter    17908     1  17:38   Apr
# 26  23  .python.dados.pandas.ipynb.sage-jupyter    19127     1  19:48   Apr
#
#           perm                              user  \
# 2   -rw-r-----  66a1613f70bc4bd082a844b07984dd6b
# 16  -rw-r-----  66a1613f70bc4bd082a844b07984dd6b
# 26  -rw-r-----  66a1613f70bc4bd082a844b07984dd6b
#
#                             usercode
# 2   66a1613f70bc4bd082a844b07984dd6b
# 16  66a1613f70bc4bd082a844b07984dd6b
# 26  66a1613f70bc4bd082a844b07984dd6b
