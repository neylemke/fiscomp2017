# %%
file=open("amaoealuva.txt","r")

# %%
texto=file.readlines()

# %%
dict={}
for line in texto:
    for word in line.split():
        if word in dict:
            dict [word]=dict[word]+1
        else:
            dict[word]=1

# %%
dict
# Out:
# {'acima,': 2,
#  'obrigaria': 1,
#  'relogio': 4,
#  'escondel-as;': 1,
#  'pundonor': 1,
#  'Foundation': 14,
#  'prazo': 1,
#  'habitual.': 2,
#  'lord': 1,
#  'emboscada': 1,
#  'serenidade': 3,
#  'readquirido': 1,
#  'suppunha;': 1,
#  "n'outro": 1,
#  'bailava-se,': 1,
#  'applaudir': 1,
#  'espa\xc3\xa7o,': 1,
#  'fidelidade': 1,
#  'algibeira': 1,
#  'Livraria': 1,
#  'dera-lhe': 4,
#  'al\xc3\xa7ando-se': 1,
#  'contemplou': 1,
#  'fez-me': 1,
#  'eleitoraes': 1,
#  'cumpriu-se': 1,
#  'pulso': 1,
#  'ficaram': 7,
#  'estragava': 1,
#  'dias...': 1,
#  'restitui-lo': 1,
#  'mais!': 1,
#  'dor;': 1,
#  'Malthus': 1,
#  'second': 2,
#  'dor,': 3,
#  'assim;': 1,
#  'admirar': 1,
#  'manifesta\xc3\xa7\xc3\xa3o': 1,
#  'agrade\xc3\xa7a': 1,
#  'convertesse': 1,
#  '\xc2\xabPorque': 1,
#  '--Tal': 1,
#  'seguimento': 1,
#  'accessed,': 1,
#  'dialogo': 1,
#  'increasing': 1,
#  'dahi': 9,
#  's\xc3\xa3o?': 1,
#  'causava-lhe': 1,
#  'ficara,': 1,
#  'abalado,': 2,
#  'interrogar': 1,
#  's\xc3\xa3o,': 1,
#  'axioma': 1,
#  'parados,': 2,
#  'linha': 1,
#  'ou...': 2,
#  'quaesquer': 2,
#  'edi\xc3\xa7\xc3\xa3o': 2,
#  'transi\xc3\xa7\xc3\xa3o,': 1,
#  'admira?': 1,
#  'levara-o,': 1,
#  'demasia': 2,
#  'DAMAGE.': 1,
#  'NOT': 2,
#  'admira,': 2,
#  'jurar': 1,
#  'detestavel,': 1,
#  'replace': 1,
#  'ambicioso,': 1,
#  '--Benef\xc3\xadcios!': 1,
#  'ambicioso.': 2,
#  'attenta': 1,
#  'attento': 2,
#  'nobres,': 1,
#  'uniu': 1,
#  'miudamente': 1,
#  'Podia': 1,
#  'indiscreta': 1,
#  'c\xc3\xb4rte': 1,
#  'autorisa\xc3\xa7\xc3\xa3o': 1,
#  'rapidamente': 5,
#  'perverso;': 1,
#  'nelle...': 1,
#  'paperwork': 1,
#  'Supponho,': 1,
#  'silenciosas,': 1,
#  'senhora.': 1,
#  'inventado': 1,
#  'officio': 4,
#  'azedume:': 1,
#  'enxugou': 1,
#  'leques,': 1,
#  '90': 2,
#  'hold': 1,
#  'ceu.': 3,
#  'liability,': 1,
#  'despendido': 1,
#  'carioca': 1,
#  'consultal-o': 1,
#  'redarguiu': 1,
#  'magestade': 1,
#  'NOTICE': 1,
#  'chamava': 2,
#  'rodeavam.': 1,
#  'organized': 1,
#  'ACTUAL,': 1,
#  'assustada': 1,
#  'ASCII"': 2,
#  'comprimentava': 1,
#  'machiavelico,': 1,
#  'sol,--o': 1,
#  'N\xc3\xa3o,': 2,
#  'chacaras': 1,
#  'permittiu': 1,
#  'damage': 1,
#  'machine': 1,
#  'how': 4,
#  'diversa': 1,
#  'ideial.': 1,
#  'permittia': 1,
#  'A': 246,
#  'gravissimos,': 1,
#  'constante': 2,
#  'preferia': 2,
#  'vel-o?': 1,
#  'preferiu': 2,
#  'possue': 1,
#  'dormiria': 1,
#  'atravez': 2,
#  'depressa.': 1,
#  'sentir': 6,
#  'Foram': 2,
#  'grudou-se': 1,
#  'sentiu': 15,
#  'chacara;': 1,
#  'calado,': 1,
#  'calado.': 1,
#  'chacara?': 1,
#  'Estev\xc3\xa3o,--\xc3\xa9': 1,
#  'continuou': 26,
#  'sentia': 5,
#  'malfadada': 1,
#  'observava-o': 1,
#  'eliminou': 1,
#  'floridas': 1,
#  'uma,--ou': 1,
#  'chacara.': 8,
#  'chacara,': 4,
#  'realidade': 6,
#  'protestante': 1,
#  'aereo,': 1,
#  'esperal-o.': 1,
#  'Aquelles': 1,
#  'reparti\xc3\xa7\xc3\xa3o': 1,
#  'nestas': 3,
#  'solu\xc3\xa7os.': 1,
#  'semestre,': 1,
#  '--Nenhuma.': 1,
#  'Dizendo': 1,
#  '--Quanto': 1,
#  'fiz': 2,
#  'fix': 1,
#  'queria-as': 1,
#  'Natal': 2,
#  'fio': 2,
#  'conter.': 1,
#  'fim': 11,
#  'mesmos,': 1,
#  'faisca,': 1,
#  '--Deveras.': 1,
#  '--Deveras!': 1,
#  'ben\xc3\xa7\xc3\xa3os': 1,
#  'Lyrico,': 1,
#  'lizo,': 1,
#  'leitura,': 1,
#  'leitura.': 1,
#  'folha': 9,
#  'Caminhou': 1,
#  'financial': 1,
#  'Gutenberg-tm': 53,
#  'identico,': 1,
#  'estabeleceu-se': 1,
#  'chegou': 7,
#  'soph\xc3\xa1,': 3,
#  'soph\xc3\xa1.': 1,
#  'matinal': 3,
#  'ri': 2,
#  'repulsa.': 1,
#  'consagra\xc3\xa7\xc3\xa3o': 1,
#  'della,': 10,
#  'della.': 5,
#  'correcta': 1,
#  'correcto': 1,
#  'precede,': 1,
#  'sagazes.': 1,
#  'della;': 1,
#  'Estev\xc3\xa3o': 113,
#  'della?': 1,
#  'gostavas': 1,
#  'permanencia': 1,
#  'bateu': 1,
#  'Guiomar': 181,
#  'bater': 4,
#  'ANYTHING': 1,
#  'sa\xc3\xad': 1,
#  '--Nenhuma....': 1,
#  'ebrio,': 1,
#  'deixar': 12,
#  'recolhera-se': 1,
#  'declinou': 1,
#  'ter\xc3\xa1': 2,
#  'modestia.': 1,
#  'purpose': 1,
#  'tantos': 3,
#  'chamavam': 1,
#  'conhecesse': 1,
#  'communs': 1,
#  'Please': 1,
#  'Gutenberg"),': 1,
#  'FITNESS': 1,
#  'polida': 2,
#  'morte...': 1,
#  'estragos': 1,
#  'seccos': 2,
#  'enfiando': 1,
#  'arrufo': 1,
#  'alcan\xc3\xa7al-o;': 1,
#  'Preferia': 1,
#  'domina.': 1,
#  'mo\xc3\xa7os': 2,
#  'procurou': 1,
#  'porem,': 1,
#  'resistiam,': 1,
#  'triste,--ainda': 1,
#  'irrita\xc3\xa7\xc3\xa3o.': 1,
#  'se...': 1,
#  'expend': 1,
#  'inesperado,': 1,
#  'castidade': 1,
#  'tanto,': 3,
#  'ser,': 5,
#  'recto': 1,
#  'sedas,': 1,
#  'mo\xc3\xa7o,': 2,
#  'mo\xc3\xa7o.': 2,
#  'reproduzir': 1,
#  'estrellas.': 1,
#  'tres': 23,
#  'old,': 1,
#  'este': 30,
#  'esta': 41,
#  'interveiu': 1,
#  'estante,': 1,
#  'estante.': 1,
#  'longo': 10,
#  'pallida': 1,
#  'longa': 2,
#  'recem-casados,': 1,
#  'longe': 16,
#  'escrever-lhe': 1,
#  'relembra': 1,
#  'sitio': 1,
#  'person': 4,
#  'chorava.': 1,
#  'saudou,': 1,
#  'cedendo': 1,
#  'receber': 2,
#  'traduzir-lhe': 1,
#  'recebeu': 6,
#  'sonho.': 1,
#  'reviveu,': 1,
#  'agu\xc3\xa7arem': 1,
#  'representavam': 1,
#  'estranhos,': 1,
#  'doia': 1,
#  'shall': 2,
#  'lan\xc3\xa7ar': 1,
#  'estantes': 1,
#  'fees,': 1,
#  'fees.': 1,
#  'fundamento,': 1,
#  'convenho;': 1,
#  '--Isso,': 1,
#  'gravidade.': 1,
#  'gravidade,': 1,
#  'mangueiras,': 1,
#  'incompleto': 1,
#  'senhoril': 1,
#  'humanos,': 1,
#  'incompleta': 1,
#  'vulgaridade.': 1,
#  'accordal-a,': 1,
#  'cegas,': 1,
#  'modo:': 1,
#  'invencivel.': 1,
#  'insecto': 1,
#  'modo,': 4,
#  'modo.': 1,
#  'Replacement': 1,
#  'copy': 8,
#  'recta,': 1,
#  'observava;': 1,
#  'holder': 1,
#  '--Sua': 1,
#  'than': 2,
#  'apagar\xc3\xa1?': 1,
#  'pedindo-lhe': 1,
#  'VII.--Um': 1,
#  'charco.': 1,
#  'descaira-lhe,': 1,
#  'modos': 3,
#  'compensado': 1,
#  'bom,': 5,
#  'lavou-se,': 1,
#  'X': 1,
#  'digamos': 1,
#  'Henriqueta.': 1,
#  'Henriqueta,': 3,
#  'lerem': 1,
#  'unisonos.': 1,
#  'SEND': 1,
#  'reflex\xc3\xa3o,': 2,
#  'electronically,': 1,
#  'XVII': 1,
#  'acabou': 7,
#  'tumultuavam': 1,
#  'matar-se': 1,
#  'chacara': 5,
#  'esquivar-se': 1,
#  'vagaroso': 1,
#  'receb\xc3\xaara.': 1,
#  'patente,': 1,
#  'trajada': 1,
#  'batera': 1,
#  'IRS.': 1,
#  'assomava': 1,
#  'annunciava': 1,
#  'ira': 1,
#  'excellentes,': 1,
#  'aprecia\xc3\xa7\xc3\xb5es;': 1,
#  'barrenta': 1,
#  'refeita,': 1,
#  'nossas': 3,
#  'entreter-me': 1,
#  'extent': 1,
#  'advertiu': 1,
#  'h\xc3\xa3o': 4,
#  'ir;': 1,
#  'manso,': 1,
#  'reported': 1,
#  'country': 4,
#  'Laura': 2,
#  'affastar-se,': 1,
#  'ir,': 2,
#  'ir.': 1,
#  'Logo': 2,
#  'offereceu,': 1,
#  'regularmente,': 1,
#  '\xef\xbb\xbfThe': 1,
#  'visitava': 1,
#  'sua.': 2,
#  'sua,': 1,
#  'sua;': 1,
#  'unprotected': 1,
#  'sua?': 1,
#  'almas.': 2,
#  'puxar': 1,
#  'pensei': 2,
#  'queria,': 1,
#  'infancia,--mas': 1,
#  'much': 1,
#  'voca\xc3\xa7\xc3\xa3o': 1,
#  '20%': 1,
#  'difficil': 4,
#  'summa,': 1,
#  'caf\xc3\xa9': 1,
#  'epistola': 1,
#  'traduc\xc3\xa7\xc3\xa3o': 2,
#  'disposi\xc3\xa7\xc3\xa3o.': 1,
#  'affoutamente': 1,
#  'vaporosas,': 1,
#  'dava': 9,
#  'suas': 27,
#  'desconsolador.': 1,
#  '(and': 1,
#  'medida': 1,
#  'impingir': 1,
#  'queriam': 2,
#  'corredor.': 1,
#  'corredor,': 1,
#  'lidava': 1,
#  'risco': 1,
#  'trocaria': 1,
#  'capitulos,--era': 1,
#  'linguagem': 1,
#  'leitor:--curiosidade': 1,
#  'desta': 17,
#  'abusar': 1,
#  'deste': 8,
#  'desappareceu,': 1,
#  'baroneza;': 6,
#  'cobria': 1,
#  'estrella....': 1,
#  'bra\xc3\xa7o,': 1,
#  'bra\xc3\xa7o.': 1,
#  'Sobre': 1,
#  'affabilidade': 3,
#  'rega\xc3\xa7o': 2,
#  'baroneza.': 22,
#  'baroneza,': 35,
#  'apontados,': 1,
#  'damaged': 1,
#  'devera': 4,
#  'sal\xc3\xa3o.': 1,
#  'things': 2,
#  'amasse': 1,
#  'naturalmente,': 2,
#  'any': 31,
#  'Infelizmente': 1,
#  'compleix\xc3\xa3o': 1,
#  'eBooks': 4,
#  'accendem': 1,
#  'memoria': 8,
#  'buscando': 2,
#  'rivalidades': 1,
#  'middle-aged': 1,
#  'bra\xc3\xa7os': 6,
#  'saida': 1,
#  'Conseguiu': 1,
#  'accendeu': 4,
#  'saido': 1,
#  'memoria.': 3,
#  'memoria,': 2,
#  'franca;': 1,
#  'principal,': 2,
#  'juridicas': 1,
#  'ermo.': 1,
#  'algum': 27,
#  'tirava': 3,
#  'tragal-o.': 1,
#  'espirito': 24,
#  'maximo': 1,
#  'academia': 1,
#  'accusar\xc3\xa1s': 1,
#  'maxima': 1,
#  'addresses.': 1,
#  'rebent\xc3\xa1ra': 1,
#  'bellos': 4,
#  'combinavam,': 1,
#  'Subito,': 1,
#  'desapareceu': 1,
#  'firme,': 1,
#  'firme.': 2,
#  'approximou-se': 2,
#  'previous': 1,
#  '--Guiomar,': 1,
#  'approximou-se,': 1,
#  '--Guiomar!': 2,
#  'repassados': 1,
#  'Interrogar': 1,
#  'has': 4,
#  'chamei-te.': 1,
#  'maviosa': 1,
#  'afivellou': 1,
#  'estremeceu,': 1,
#  'estremeceu.': 1,
#  'suffocado': 1,
#  'desfazia,': 1,
#  'esconder': 2,
#  'escondeu': 1,
#  'graciosas': 1,
#  'contentamento': 1,
#  'ha,': 2,
#  'ha.': 2,
#  'promette': 1,
#  'collection.': 1,
#  'pausado': 1,
#  'Imaginei': 1,
#  'calada;': 1,
#  'complexo': 1,
#  'Golpe.': 1,
#  'vinte': 9,
#  'old': 1,
#  'whenever': 1,
#  'Escolhes': 1,
#  'people': 3,
#  'devorar': 1,
#  'musculos,': 1,
#  'atten\xc3\xa7\xc3\xa3o': 3,
#  'Estas': 3,
#  'enxutas.': 1,
#  'reparo': 1,
#  'queria-os': 1,
#  'for': 25,
#  'arrancadas': 1,
#  'embry\xc3\xa3o': 1,
#  'muito': 54,
#  'maneira': 11,
#  'uma': 238,
#  'afinal': 2,
#  'comprimentar': 1,
#  'entretanto': 2,
#  'reuniu.': 1,
#  '--Digamos': 1,
#  'foi': 94,
#  'muita': 14,
#  'inclinou': 1,
#  'estremecimento': 1,
#  'Esta,': 1,
#  'contemplando': 1,
#  'culpa.': 1,
#  'alterado': 1,
#  'Mme.': 1,
#  'esperar,': 1,
#  'confessava': 2,
#  'principaes,': 1,
#  'o': 867,
#  'emboscada,': 1,
#  'Estev\xc3\xa3o.--Minha': 1,
#  'um,': 2,
#  'um.': 1,
#  'um)': 1,
#  'apagou-se': 1,
#  'Use': 2,
#  'sob': 1,
#  'abundancia': 2,
#  'tra\xc3\xa7o': 1,
#  'desacertara': 1,
#  'sol': 9,
#  'vagando': 1,
#  'sou': 11,
#  'CONSEQUENTIAL,': 1,
#  'conclua,': 1,
#  'novo': 10,
#  'conselhos.': 1,
#  'levava': 1,
#  'peso,': 1,
#  'nove': 2,
#  'nova': 3,
#  'ahi.': 1,
#  'viuva': 4,
#  'seguia': 2,
#  'vontade': 7,
#  'commento,': 1,
#  'cama;': 1,
#  'mostrou-se': 1,
#  'sobrava-lhe': 1,
#  'talento': 1,
#  'cama.': 1,
#  'seguir': 4,
#  'seguiu': 2,
#  'Supporia': 1,
#  'satisfa\xc3\xa7\xc3\xa3o': 7,
#  'amorosos': 1,
#  'gra\xc3\xa7a.': 1,
#  'cumpria': 1,
#  'ninguem;': 2,
#  'humano,': 1,
#  'sentar-se-agora;': 1,
#  'humano.': 1,
#  'peso': 4,
#  'Tambem': 1,
#  'pensamento': 6,
#  '--....': 1,
#  'cumprir': 1,
#  'adiante.': 1,
#  'cincoenta': 2,
#  'exprimia': 1,
#  'decidisse': 1,
#  'ninguem,': 1,
#  'Sir': 1,
#  'rematavam': 1,
#  'dividida,': 1,
#  'historias.': 1,
#  'allegando': 3,
#  'infancia.': 1,
#  'setimo.': 1,
#  'infancia,': 1,
#  'zombaria...': 1,
#  'tenazmente': 1,
#  'solicitation': 1,
#  'energica,': 1,
#  'actos': 1,
#  '--Mas': 9,
#  '--Porque': 2,
#  'Voluntariamente,': 1,
#  'graduado': 1,
#  'adormecer': 1,
#  'VIII.--Golpe': 1,
#  'E': 30,
#  'tarde,': 7,
#  'refulgia': 1,
#  'juvenil.': 1,
#  'augmentada': 1,
#  'tarde;': 3,
#  'editaria': 1,
#  'palma': 1,
#  'aproar': 1,
#  'replacement': 3,
#  '[EBook': 1,
#  'e,--tamanho': 1,
#  'me\xc3\xa7as,': 1,
#  'entr\xc3\xa1ra': 1,
#  'inclinou-se': 3,
#  'respeito;': 1,
#  'ouvir-me-has': 1,
#  'vencidos': 1,
#  'deixara': 3,
#  'durou': 9,
#  'urgia': 1,
#  'dotes': 1,
#  'nome.': 1,
#  '--Disseram-me,': 1,
#  'revellar': 1,
#  'padece': 1,
#  'entrevista': 2,
#  'fosca,': 1,
#  'nome:': 2,
#  'nome;': 1,
#  'enxutos,': 1,
#  '--Seria': 1,
#  'preferisses': 1,
#  'expor-se': 1,
#  'veem.': 1,
#  'davam': 1,
#  'affecta\xc3\xa7\xc3\xa3o,': 2,
#  'veu': 3,
#  'ver': 36,
#  '--Elegantissimo,': 1,
#  'infantilmente': 1,
#  'infortunios,': 1,
#  'vez': 45,
#  'fic\xc3\xa1ra.': 1,
#  'fic\xc3\xa1ra,': 1,
#  'encubram,': 1,
#  'distinguia': 1,
#  'Volveu': 1,
#  'recolhi,': 1,
#  'crendice': 1,
#  'vem': 4,
#  'affecto': 7,
#  'saindo': 1,
#  'recolhesse.': 1,
#  'minuto': 3,
#  'mouro': 2,
#  '--Ser\xc3\xa1': 2,
#  'saude.': 1,
#  'saude,': 1,
#  'nomes': 1,
#  'absorvia.': 1,
#  'querem': 1,
#  'gamenho': 1,
#  'habil;': 1,
#  'querer': 7,
#  'queres': 3,
#  'Viu-a': 1,
#  'Tal': 3,
#  'propor\xc3\xa7\xc3\xb5es': 1,
#  'prevent': 1,
#  'tempos;': 1,
#  'percebi': 2,
#  'Date:': 1,
#  'boca': 2,
#  '--Vieste': 1,
#  'tempos,': 3,
#  'Edimburgo.': 1,
#  'hontem.': 1,
#  'voltei': 1,
#  'hontem,': 2,
#  'estremeceu': 2,
#  'current': 1,
#  'alumna-professora': 1,
#  'Gutenberg:': 1,
#  'Alves.': 20,
#  'Alves,': 25,
#  'recorda\xc3\xa7\xc3\xb5es,--as': 1,
#  'Alves;': 3,
#  'suppriu': 1,
#  'Alves?': 2,
#  'address': 1,
#  'alone': 1,
#  'Gutenberg"': 4,
#  'prezas': 1,
#  'S\xc3\xb3': 1,
#  'recruta': 1,
#  'attonito': 1,
#  'algu\xc3\xa9m': 1,
#  'enlevado': 1,
#  'recep\xc3\xa7\xc3\xa3o,': 1,
#  'Relanceando': 1,
#  'propenso': 1,
#  'XIII.--Explica\xc3\xa7\xc3\xb5es': 1,
#  'Vivia': 1,
#  'Antes': 1,
#  'cathegoria': 1,
#  'READ': 1,
#  'specified': 2,
#  'DOS': 1,
#  'crime': 1,
#  'XVIII': 1,
#  'finas,': 1,
#  'disso.': 2,
#  'logo:': 1,
#  'logo;': 3,
#  'candidatura': 1,
#  'Disse-lhe,': 1,
#  'coleras': 1,
#  'curioso': 4,
#  'leitores': 1,
#  'logo.': 2,
#  'logo,': 1,
#  'aperfei\xc3\xa7oava': 1,
#  'ingleza': 26,
#  'custa-me': 1,
#  'beneficio': 1,
#  'stored,': 1,
#  'pedia;--a': 1,
#  '\xc2\xabpost-scriptum\xc2\xbb...': 1,
#  'socegado': 1,
#  'amado': 1,
#  'Bragaldi,': 1,
#  '"Information': 1,
#  'gra\xc3\xa7as;': 1,
#  'colera.': 2,
#  'colera,': 2,
#  'anciava': 1,
#  'pendente,': 1,
#  'ber\xc3\xa7o': 1,
#  'fossem': 7,
#  'Guiomar!': 1,
#  'casamento,': 3,
#  'trazer': 2,
#  'justo': 1,
#  'Guiomar.': 36,
#  'disso?': 5,
#  'dizer-te.': 1,
#  'casamento;': 1,
#  'one--the': 1,
#  'casamento?': 1,
#  'Guiomar?': 3,
#  'bastante': 7,
#  'Guiomar;': 9,
#  'drama': 1,
#  'ressaca,': 1,
#  'calou-se': 2,
#  'fosse.': 1,
#  'fosse,': 1,
#  'garganta.': 1,
#  'garganta,': 1,
#  'balbuciou:': 1,
#  "Foundation's": 3,
#  'assentada;': 1,
#  'fosse;': 2,
#  'egualava,': 2,
#  'date': 2,
#  'such': 5,
#  'chamaremos--voluptuosidade': 1,
#  'dispensou': 1,
#  'egoismo,': 1,
#  'natural': 17,
#  'menos,': 14,
#  'menos.': 3,
#  'Meninice.': 1,
#  'acertara;': 1,
#  'si': 24,
#  'so': 3,
#  'militava': 1,
#  'se': 281,
#  'unsolicited': 1,
#  'principio': 8,
#  'sympathia,': 2,
#  'murmurar': 1,
#  'sympathia.': 1,
#  'deito': 1,
#  'below.': 3,
#  'frequente': 1,
#  'sorte.': 1,
#  'Dir\xc3\xa1': 1,
#  'antes.': 6,
#  'antes,': 4,
#  'somno': 4,
#  'Veiu': 1,
#  'desnorteou-a': 1,
#  'querida,': 1,
#  'tel-as': 1,
#  'homenagens': 1,
#  'entrada': 1,
#  'vinculassem': 1,
#  '--Dormiu': 1,
#  'concebera,': 1,
#  'adoradores!': 1,
#  'surdamente': 2,
#  'entraram': 1,
#  'temeu': 1,
#  'respeitoso': 1,
#  'respeitosa': 1,
#  'torn\xc3\xa1ra-se': 1,
#  'maintaining': 1,
#  'disfar\xc3\xa7ar': 1,
#  'proximas,': 1,
#  'acabassem': 1,
#  'preconceitos,': 1,
#  'fazer-me': 1,
#  'repellir': 1,
#  'repelliu': 2,
#  'concluir\xc3\xa1': 1,
#  '\xc2\xabtal': 1,
#  'prefere;': 1,
#  'apparecido': 1,
#  'devorado': 1,
#  'mim;': 1,
#  'receipt': 2,
#  'bellas': 4,
#  'acceitasse,': 1,
#  'mim,': 6,
#  'superior,': 1,
#  'mim.': 1,
#  'brancas': 1,
#  'hora,': 7,
#  'hora.': 2,
#  'hora!': 2,
#  '--Dou-lhe': 1,
#  'abide': 1,
#  'hora;': 1,
#  'travar': 1,
#  'sereno,': 1,
#  'attenua\xc3\xa7\xc3\xa3o': 1,
#  'inconsistentes,': 1,
#  'veus,': 1,
#  'bella,': 1,
#  'sentes': 1,
#  'Terminado': 1,
#  'chinellas,': 1,
#  'mimo': 1,
#  'destacava': 1,
#  '--S\xc3\xa3o': 2,
#  '1874.': 1,
#  'seguirem': 1,
#  "d'aquillo": 1,
#  'horas': 8,
#  'seda': 1,
#  'maiores': 1,
#  'parecia,': 3,
#  'p\xc3\xb4r': 3,
#  'vacuo': 1,
#  'saleta.': 1,
#  'saleta,': 1,
#  'voto': 2,
#  'particularismo': 1,
#  'almas': 2,
#  'raro,': 1,
#  'diccionarios.': 1,
#  'Plutarcho': 1,
#  'favor?': 1,
#  'retrahimento.': 1,
#  'indicate': 1,
#  'preencher': 1,
#  'types': 1,
#  'explicasse': 1,
#  'impor-lhe': 1,
#  'parando': 3,
#  'apertaram': 1,
#  'on,': 1,
#  'acc\xc3\xb4rdo': 1,
#  'pareciam': 5,
#  'probabilidade': 1,
#  'alma,': 6,
#  'amargas,': 1,
#  '1.E.8': 2,
#  'affoutos.': 1,
#  '--Estou': 2,
#  '1.E.7': 2,
#  'mescla': 1,
#  'bebeu': 1,
#  'alma;': 2,
#  "d'alma": 1,
#  'secca.': 1,
#  'detraz': 1,
#  'rival': 1,
#  'presen\xc3\xa7a': 11,
#  "beijou-lh'a": 1,
#  'future': 3,
#  'futuro': 5,
#  'lyrico,': 1,
#  'admirando': 2,
#  'triste!': 1,
#  'triste.': 1,
#  'triste,': 3,
#  'conselhos': 1,
#  'correc\xc3\xa7\xc3\xb5es': 1,
#  'locations': 1,
#  'sae': 1,
#  'delles': 6,
#  'reter': 1,
#  'buscada': 1,
#  'perder-se': 1,
#  'construido': 1,
#  'adivinhava': 2,
#  'mangas': 1,
#  'adora\xc3\xa7\xc3\xa3o,': 1,
#  'apoio,': 1,
#  'law.': 2,
#  'opposi\xc3\xa7\xc3\xa3o': 1,
#  'locations.': 1,
#  'incompat\xc3\xadvel': 1,
#  'maximum': 1,
#  'nota': 1,
#  'santissima:': 1,
#  'Congresso,': 1,
#  'desconfian\xc3\xa7a,': 1,
#  's/he': 1,
#  'percebido.': 1,
#  'rid\xc3\xadculo,': 1,
#  'delle;': 2,
#  'bordadas': 1,
#  'aurora.': 2,
#  'delle,': 11,
#  'desejo,--ou': 1,
#  'inspirava-lhe': 1,
#  'propunha': 2,
#  'crean\xc3\xa7a': 5,
#  'educada.': 1,
#  'rompeu': 7,
#  'Portuguese': 1,
#  'felizes;': 1,
#  'vasto': 2,
#  'City,': 1,
#  'sala': 7,
#  'vasta': 1,
#  'dizia-lhe:': 1,
#  'acabado': 1,
#  'viagem?': 2,
#  'viagem!': 1,
#  'prepare': 1,
#  'felizes,': 1,
#  'esquecido.': 1,
#  'batia': 7,
#  'mancebo,': 1,
#  'viagem,': 3,
#  "Gutenberg-tm's": 1,
#  'viagem.': 3,
#  'laws': 9,
#  'dizia': 10,
#  'labios;': 1,
#  'vulgarisei': 1,
#  'deu-lhe': 4,
#  'quizeres.': 1,
#  'indigna\xc3\xa7\xc3\xa3o': 1,
#  'moradora,': 1,
#  'obtivera.': 1,
#  'labios.': 2,
#  'labios,': 1,
#  'ella,--ou': 1,
#  "lh'os": 1,
#  'agrestes': 1,
#  'esboroava': 1,
#  'subil-a': 1,
#  'outside': 3,
#  'Effectivamente': 1,
#  '--Acho-a': 1,
#  'genero': 4,
#  'usual.': 1,
#  'poetou,': 1,
#  'XII': 1,
#  'dezeseis': 1,
#  'noiva,': 2,
#  'curiosidade.': 1,
#  'curiosidade,': 3,
#  'sorrir,': 5,
#  'XIX': 1,
#  'maviosos': 1,
#  'descer': 2,
#  'Seguiu-se': 2,
#  'elles,': 1,
#  'desceu': 4,
#  'silencio': 11,
#  'agreste,': 1,
#  'where': 5,
#  'diria': 4,
#  'empregar': 1,
#  'amor;': 2,
#  'regressou': 1,
#  'amor?': 1,
#  'emquanto': 3,
#  'confuso': 1,
#  'liberdade': 1,
#  'gra\xc3\xa7as': 4,
#  'amor.': 5,
#  'deferiu': 1,
#  'amor,': 11,
#  'fluctuavam': 1,
#  'mesma.': 4,
#  'mesma,': 7,
#  'lagrimas': 8,
#  'tocou': 2,
#  'vestida,': 1,
#  'paciencia': 1,
#  'gra\xc3\xa7a,': 3,
#  ...}

# %%
import numpy as np
oco=dict.values()
oco.sort()
oco.reverse()
X=np.array(range(len(oco)))+1
Y=np.array(oco)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
x = fig.gca()
plt.plot(oco)
ax.set_title('Repeticao das palavras')
ax.set_xlabel('Ranking')
ax.set_ylabel('Repeticao')

# %%
logx=np.log(X)
logy=np.log(Y)
ig = plt.figure(figsize=(10,10))
ax = fig.gca()
x = fig.gca()
plt.plot(logx, logy)
ax.set_title('Repeticao das palavras')
ax.set_xlabel('Ranking')
ax.set_ylabel('Repeticao')

# %%
##EXERCICIO2

# %%
def read_auto_data(fileName = "Automobile price data.csv"):
    'Function to load the auto price data set from a .csv file' 
    import pandas as pd
    import numpy as np

    ## Read the .csv file with the pandas read_csv method
    auto_prices = pd.read_csv(fileName)
    
    ## Remove rows with missing values, accounting for mising values coded as '?'
    cols = ['price', 'bore', 'stroke', 
          'horsepower', 'peak-rpm']
    for column in cols:
        auto_prices.loc[auto_prices[column] == '?', column] = np.nan
    auto_prices.dropna(axis = 0, inplace = True)

    ## Convert some columns to numeric values
    for column in cols:
        auto_prices[column] = pd.to_numeric(auto_prices[column])
#    auto_prices[cols] = auto_prices[cols].as_type(int64)
        
    return auto_prices
auto_prices = read_auto_data()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 10)) # define plot area
ax = fig.gca() # define axis                   
auto_prices.plot(kind = 'scatter', x = 'engine-size', y = 'price', ax = ax)
ax.set_title('Scatter plot de tamanho do motor vs preco') # Give the plot a main title
ax.set_xlabel('Tamanho do motor') # Set text for the x axis
ax.set_ylabel('Preco, (US$)')# Set text for y axis
