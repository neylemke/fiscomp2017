# %% [markdown]
# ### Exercícios de Revisão

# %% [markdown]
# #### Exercicio 1
# - Gere uma lista com 100 números aleatórios, em seguida o aluno deverá deverá encontrar os intervalos médios dos elementos da lista.

# %%
import random

# %%
L=random.sample(range(0,100),100)

# %%
L
# Out:
# [47,
#  17,
#  12,
#  0,
#  32,
#  6,
#  46,
#  77,
#  21,
#  96,
#  48,
#  71,
#  25,
#  4,
#  37,
#  62,
#  87,
#  65,
#  36,
#  34,
#  33,
#  45,
#  31,
#  68,
#  99,
#  15,
#  64,
#  97,
#  28,
#  11,
#  43,
#  69,
#  56,
#  49,
#  76,
#  54,
#  66,
#  1,
#  72,
#  52,
#  2,
#  35,
#  79,
#  61,
#  23,
#  83,
#  59,
#  42,
#  98,
#  90,
#  88,
#  78,
#  63,
#  89,
#  14,
#  38,
#  44,
#  20,
#  9,
#  86,
#  27,
#  53,
#  19,
#  75,
#  40,
#  94,
#  84,
#  57,
#  8,
#  67,
#  26,
#  51,
#  22,
#  41,
#  60,
#  13,
#  16,
#  58,
#  93,
#  7,
#  74,
#  29,
#  82,
#  80,
#  73,
#  81,
#  39,
#  50,
#  24,
#  95,
#  70,
#  30,
#  18,
#  55,
#  10,
#  85,
#  5,
#  91,
#  92,
#  3]

# %%
soma=0
L1=[]
for i in range(0,99):
    L1.append((L[i]-L[i+1]))
    soma=soma+(L[i]-L[i+1])
media=soma/99
print(L1)
print("O interlavo médio sera de:",media)
# Out:
# [30, 5, 12, -32, 26, -40, -31, 56, -75, 48, -23, 46, 21, -33, -25, -25, 22, 29, 2, 1, -12, 14, -37, -31, 84, -49, -33, 69, 17, -32, -26, 13, 7, -27, 22, -12, 65, -71, 20, 50, -33, -44, 18, 38, -60, 24, 17, -56, 8, 2, 10, 15, -26, 75, -24, -6, 24, 11, -77, 59, -26, 34, -56, 35, -54, 10, 27, 49, -59, 41, -25, 29, -19, -19, 47, -3, -42, -35, 86, -67, 45, -53, 2, 7, -8, 42, -11, 26, -71, 25, 40, 12, -37, 45, -75, 80, -86, -1, 89]
# O interlavo médio sera de: 0.4444444444444444

# %% [markdown]
# #### Exercicio 2
# Faça um programa que leia um número indeterminado de valores, correspondentes a notas, encerrando a entrada de dados quando for informado um valor igual a -1 (que não deve ser armazenado). Após esta entrada de dados, faça:
# - Mostre a quantidade de valores que foram lidos;
# - Exiba todos os valores na ordem em que foram informados, um ao lado do outro;
# - Exiba todos os valores na ordem inversa à que foram informados, um abaixo do outro;
# - Calcule e mostre a soma dos valores;
# - Calcule e mostre a média dos valores;
# - Calcule e mostre a quantidade de valores acima da média calculada;
# - Calcule e mostre a quantidade de valores abaixo de sete;
# - Encerre o programa com uma mensagem;

# %%
N=[]
Num=0
while Num!=-1:
    Num=float(input("Insira a nota:"))
    if Num!=-1:
        N=N+[Num]
print("foram lidos:",len(N))


i=0
print("As notas que foram inseridas:")
N1=""
for elem in N:
    N1=N1+str(elem)+"\n"
print (N1)

Nr=[]
i=0
print("As notas em ordem inversa será:")
while i<len(N):
    Nr=Nr+[N[len(N)-1-i]]
    i+=1

N2=""
for elem in Nr:
    N2=N2+str(elem)+"\n"
print(N2)


i=0
soma=0
while i<len(N):
    soma=soma+N[i]
    i+=1
print("A soma será:", soma)
md=soma/len(N)
print("A media sera:", md)



i=0
A=[]
while i<len(N):
    if N[i]>md:
        A=A+[N[i]]
    i+=1
print("A quatidade de notas acima da media sera:", len(A))


i=0
baixas=[]
while i<len(N):
    if N[i]<md:
        baixas=baixas+[N[i]]
    i+=1
print("A quatidade de notas abaixo da media e de:", len(baixas))


if md>=5:
    print("O aluno foi aprovado na materia!")
else:
    print("O aluno foi reprovado na materia!")
# Out:
# Insira a nota: 2
# Insira a nota: 3
# Insira a nota: 5
# Insira a nota: -1
# foram lidos: 3
# As notas que foram inseridas:
# 2.0
# 3.0
# 5.0
#
# As notas em ordem inversa será:
# 5.0
# 3.0
# 2.0
#
# A soma será: 10.0
# A media sera: 3.3333333333333335
# A quatidade de notas acima da media sera: 1
# A quatidade de notas abaixo da media e de: 2
# O aluno foi reprovado na materia!

# %% [markdown]
# #### Exercicio 3
# - Calcule as raízes da equação do 2◦ grau ($Ax^2 + Bx + C = 0$) sendo os valores de A, B e C fornecidos pelo usuário, levando em consideração a existência de raízes complexas.**

# %%
print("A cara da equacao e de: A*x**2 + B*x + C = 0.")
A=float(input("Insira o valor de A."))
B=float(input("Insira o valor de B."))
C=float(input("Insira o valor de C."))
delta=(B**2-4*A*C)**(1/2)
X1=(-B+delta)/(2*A)
print ("A primeira raiz sera:", X1)
X2=(-B-delta)/(2*A)
print("A segunda raiz sera:", X2)
# Out:
# A cara da equacao e de: A*x**2 + B*x + C = 0.
# Insira o valor de A. 1
# Insira o valor de B. 2
# Insira o valor de C. 3
# A primeira raiz sera: (-0.9999999999999999+1.4142135623730951j)
# A segunda raiz sera: (-1-1.4142135623730951j)

# %% [markdown]
# #### Exercícios 4
# - Crie 12 arquivos, chamados de 'arq_mes_estação.txt'. Cada um deles contendo a frase: "A minha estação predileta é 'estação', especialmente 'mês'"  repetida um número aleatório de vezes, entre 5 e 20. Comprima essas arquivos usando o comando gzip. Faça isso utilizando o conceito de dicionários.

# %%
import random

# %%
# %%writefile arq_janeiro_verão.txt
# A minha estação predileta é o Verão, especialmente em janeiro.
# Out:
# Overwriting arq_janeiro_verão.txt

# %%
r=random.randint(5,20)
i=0
while i<r:
    with open('arq_janeiro_verão.txt', 'r') as f:
        print(f.read())
    i+=1
# Out:
# A minha estação predileta é o Verão, especialmente em janeiro.
# A minha estação predileta é o Verão, especialmente em janeiro.
# A minha estação predileta é o Verão, especialmente em janeiro.
# A minha estação predileta é o Verão, especialmente em janeiro.
# A minha estação predileta é o Verão, especialmente em janeiro.
# A minha estação predileta é o Verão, especialmente em janeiro.
# A minha estação predileta é o Verão, especialmente em janeiro.

# %%
# %%writefile arq_fevereiro_verão.txt
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.
# Out:
# Overwriting arq_fevereiro_verão.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_fevereiro_verão.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.
# A minha estação predileta é o verão, especialmente o mês de Fevereiro.

# %%
# %%writefile arq_março_outono.txt
# A minha estação predileta é o outono, especialmente o mês de Março.
# Out:
# Overwriting arq_março_outono.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_março_outono.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o outono, especialmente o mês de Março.
# A minha estação predileta é o outono, especialmente o mês de Março.
# A minha estação predileta é o outono, especialmente o mês de Março.
# A minha estação predileta é o outono, especialmente o mês de Março.
# A minha estação predileta é o outono, especialmente o mês de Março.
# A minha estação predileta é o outono, especialmente o mês de Março.
# A minha estação predileta é o outono, especialmente o mês de Março.

# %%
# %%writefile arq_abril_outono.txt
# A minha estação predileta é o outono, especialmente o mês de abril
# Out:
# Overwriting arq_abril_outono.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_abril_outono.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril
# A minha estação predileta é o outono, especialmente o mês de abril

# %%
# %%writefile arq_maio_outono.txt
# A minha estação predileta é o outono, especialmente o mês de maio.
# Out:
# Overwriting arq_maio_outono.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_maio_outono.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o outono, especialmente o mês de maio.
# A minha estação predileta é o outono, especialmente o mês de maio.
# A minha estação predileta é o outono, especialmente o mês de maio.
# A minha estação predileta é o outono, especialmente o mês de maio.
# A minha estação predileta é o outono, especialmente o mês de maio.
# A minha estação predileta é o outono, especialmente o mês de maio.
# A minha estação predileta é o outono, especialmente o mês de maio.

# %%
# %%writefile arq_junho_outono.txt
# A minha estação predileta é a outono, especialmente o mês de junho.
# Out:
# Overwriting arq_junho_outono.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_junho_outono.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.
# A minha estação predileta é a outono, especialmente o mês de junho.

# %%
# %%writefile arq_julho_inverno.txt
# A minha estação predileta é o inverno, especialmente o mês de julho.
# Out:
# Overwriting arq_julho_inverno.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_julho_inverno.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.
# A minha estação predileta é o inverno, especialmente o mês de julho.

# %%
# %%writefile arq_agosto_inverno.txt
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# Out:
# Overwriting arq_agosto_inverno.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_agosto_inverno.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.
# A minha estação predileta é o inverno, especialmente o mês de agosto.

# %%
# %%writefile arq_setembro_inverno.txt
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# Out:
# Overwriting arq_setembro_inverno.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_setembro_inverno.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.
# A minha estação predileta é o inverno, especialmente o mês de setembro.

# %%
# %%writefile arq_outubro_primavera.txt
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# Out:
# Overwriting arq_outubro_primavera.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_outubro_primavera.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.
# A minha estação predileta é a primavera, especialmente o mês de outubro.

# %%
# %%writefile arq_novembro_primavera.txt
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# Out:
# Overwriting arq_novembro_primavera.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_novembro_primavera.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.
# A minha estação predileta é a primavera, especialmente o mês de novembro.

# %%
# %%writefile arq_dezembro_verão.txt
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# Out:
# Overwriting arq_dezembro_verão.txt

# %%
r=random.randint(5,20)
for i in range(0,r):
    with open('arq_dezembro_verão.txt','r') as f:
        print(f.read())
# Out:
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.
# A minha estação predileta é o verão, especialmente o mês de Dezembro.

# %% [markdown]
# #### Exercícios 5
# 1. Com base nos dados de https://pt.wikipedia.org/wiki/Lista_de_epis%C3%B3dios_de_Pok%C3%A9mon Construa um  dataframe para armazenar
# as informações sobre os episódios de Pokemon, contendo:
# - Série
# - Geração
# - Temporada
# - Primeiro Episódio
# - Último Episódio
# - Região
# 2. Descubra qual a geração mais longeva
# 3. Descubra quantas temporadas durou cada série

# %%
import pandas as pd

# %%
dict=[{'Série':'Série Original' , 'Geração':'Primeira' , 'Temporada':'Liga Índigo', 'Primeiro Episódio':'000' , 'Último Episódio':'083', 'Região':'Kanto'},
      {'Série': 'Série Original' , 'Geração':'Primeira' , 'Temporada':'Aventuras na Ilha Laranja' , 'Primeiro Episódio':'084' , 'Último Episódio':'118' , 'Região':'Ilhas Laranjas'},
     {'Série':'Séria Original' , 'Geração':'Segunda' , 'Temporada':'A Jornada de Johto' , 'Primeiro Episódio':'119' , 'Último Episódio':'159' , 'Região':'Johyo'},
     {'Série':'Séria Original' , 'Geração':'Segunda' , 'Temporada':'Campeões da Liga de Jhoto' , 'Primeiro Episódio':'160' , 'Último Episódio':'211' , 'Região':'Johyo'},
     {'Série':'Séria Original' , 'Geração':'Segunda' , 'Temporada':'Master Quest' , 'Primeiro Episódio':'212' , 'Último Episódio':'276' , 'Região':'Johyo'},
     {'Série':'Geração Avançada' , 'Geração':'Terçeira' , 'Temporada':'Pokémon: Avançado' , 'Primeiro Episódio':'277' , 'Último Episódio':'316' , 'Região':'Hoenn'},
     {'Série':'Geração Avançada' , 'Geração':'Terçeira' , 'Temporada':'Desafio Avançado' , 'Primeiro Episódio':'317' , 'Último Episódio':'368' , 'Região':'Hoenn'},
     {'Série':'Geração Avançada' , 'Geração':'Terçeira' , 'Temporada':'Batalha Avançada' , 'Primeiro Episódio':'369' , 'Último Episódio':'421' , 'Região':'Hoenn'},
     {'Série':'Geração Avançada' , 'Geração':'Terçeira' , 'Temporada':'Batalha da Fronteira' , 'Primeiro Episódio':'422' , 'Último Episódio':'468' , 'Região':'Kanto'},
     {'Série':'Diamante e Pérola' , 'Geração':'Qarta' , 'Temporada':'Diamante e Pérola' , 'Primeiro Episódio':'469' , 'Último Episódio':'520' , 'Região':'Sinnoh'},
     {'Série':'Diamante e Pérola' , 'Geração':'Qarta' , 'Temporada':'Batalha Dimensional' , 'Primeiro Episódio':'521' , 'Último Episódio':'572' , 'Região':'Sinnoh'},
     {'Série':'Diamante e Pérola' , 'Geração':'Qarta' , 'Temporada':'Batalha Glácticas' , 'Primeiro Episódio':'573' , 'Último Episódio':'625' , 'Região':'Sinnoh'},
     {'Série':'Diamante e Pérola' , 'Geração':'Qarta' , 'Temporada':'Vencedores da Liga Sinnoh' , 'Primeiro Episódio':'626' , 'Último Episódio':'659' , 'Região':'Sinnoh'},
     {'Série':'Preto e Branco' , 'Geração':'Quinta' , 'Temporada':'Preto e Branco' , 'Primeiro Episódio':'660' , 'Último Episódio':'707' , 'Região':'Unova'},
     {'Série':'Preto e Branco' , 'Geração':'Quinta' , 'Temporada':'Destinos Rivais' , 'Primeiro Episódio':'708' , 'Último Episódio':'756' , 'Região':'Unova'},
     {'Série':'Preto e Branco' , 'Geração':'Quinta' , 'Temporada':'Aventuras em Unova (e Mais Além)' , 'Primeiro Episódio':'757' , 'Último Episódio':'803' , 'Região':'Unova'},
     {'Série':'XY' , 'Geração':'Sexta' , 'Temporada':'A Série XY' , 'Primeiro Episódio':'804' , 'Último Episódio':'852' , 'Região':'Kalos'},
     {'Série':'XY' , 'Geração':'Sexta' , 'Temporada':'Kalos Quest' , 'Primeiro Episódio':'853' , 'Último Episódio':'897' , 'Região':'Kalos'},
     {'Série':'XY' , 'Geração':'Sexta' , 'Temporada':'XY e Z' , 'Primeiro Episódio':'898' , 'Último Episódio':'946' , 'Região':'Kalos'},
     {'Série':'Sun and Moon' , 'Geração':'Sétima' , 'Temporada':'Sun and Moon' , 'Primeiro Episódio':'947' , 'Último Episódio':'--' , 'Região':'Alola'}]
df=pd.DataFrame(dict)
df[['Série' , 'Geração' , 'Temporada' , 'Primeiro Episódio' , 'Último Episódio', 'Região']]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Série</th>
#       <th>Geração</th>
#       <th>Temporada</th>
#       <th>Primeiro Episódio</th>
#       <th>Último Episódio</th>
#       <th>Região</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Série Original</td>
#       <td>Primeira</td>
#       <td>Liga Índigo</td>
#       <td>000</td>
#       <td>083</td>
#       <td>Kanto</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Série Original</td>
#       <td>Primeira</td>
#       <td>Aventuras na Ilha Laranja</td>
#       <td>084</td>
#       <td>118</td>
#       <td>Ilhas Laranjas</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Séria Original</td>
#       <td>Segunda</td>
#       <td>A Jornada de Johto</td>
#       <td>119</td>
#       <td>159</td>
#       <td>Johyo</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Séria Original</td>
#       <td>Segunda</td>
#       <td>Campeões da Liga de Jhoto</td>
#       <td>160</td>
#       <td>211</td>
#       <td>Johyo</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Séria Original</td>
#       <td>Segunda</td>
#       <td>Master Quest</td>
#       <td>212</td>
#       <td>276</td>
#       <td>Johyo</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Geração Avançada</td>
#       <td>Terçeira</td>
#       <td>Pokémon: Avançado</td>
#       <td>277</td>
#       <td>316</td>
#       <td>Hoenn</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Geração Avançada</td>
#       <td>Terçeira</td>
#       <td>Desafio Avançado</td>
#       <td>317</td>
#       <td>368</td>
#       <td>Hoenn</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Geração Avançada</td>
#       <td>Terçeira</td>
#       <td>Batalha Avançada</td>
#       <td>369</td>
#       <td>421</td>
#       <td>Hoenn</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Geração Avançada</td>
#       <td>Terçeira</td>
#       <td>Batalha da Fronteira</td>
#       <td>422</td>
#       <td>468</td>
#       <td>Kanto</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Diamante e Pérola</td>
#       <td>Qarta</td>
#       <td>Diamante e Pérola</td>
#       <td>469</td>
#       <td>520</td>
#       <td>Sinnoh</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Diamante e Pérola</td>
#       <td>Qarta</td>
#       <td>Batalha Dimensional</td>
#       <td>521</td>
#       <td>572</td>
#       <td>Sinnoh</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Diamante e Pérola</td>
#       <td>Qarta</td>
#       <td>Batalha Glácticas</td>
#       <td>573</td>
#       <td>625</td>
#       <td>Sinnoh</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Diamante e Pérola</td>
#       <td>Qarta</td>
#       <td>Vencedores da Liga Sinnoh</td>
#       <td>626</td>
#       <td>659</td>
#       <td>Sinnoh</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Preto e Branco</td>
#       <td>Quinta</td>
#       <td>Preto e Branco</td>
#       <td>660</td>
#       <td>707</td>
#       <td>Unova</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Preto e Branco</td>
#       <td>Quinta</td>
#       <td>Destinos Rivais</td>
#       <td>708</td>
#       <td>756</td>
#       <td>Unova</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Preto e Branco</td>
#       <td>Quinta</td>
#       <td>Aventuras em Unova (e Mais Além)</td>
#       <td>757</td>
#       <td>803</td>
#       <td>Unova</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>XY</td>
#       <td>Sexta</td>
#       <td>A Série XY</td>
#       <td>804</td>
#       <td>852</td>
#       <td>Kalos</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>XY</td>
#       <td>Sexta</td>
#       <td>Kalos Quest</td>
#       <td>853</td>
#       <td>897</td>
#       <td>Kalos</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>XY</td>
#       <td>Sexta</td>
#       <td>XY e Z</td>
#       <td>898</td>
#       <td>946</td>
#       <td>Kalos</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Sun and Moon</td>
#       <td>Sétima</td>
#       <td>Sun and Moon</td>
#       <td>947</td>
#       <td>--</td>
#       <td>Alola</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df[['Primeiro Episódio' , 'Último Episódio']]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Primeiro Episódio</th>
#       <th>Último Episódio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>000</td>
#       <td>083</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>084</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>119</td>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>160</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>212</td>
#       <td>276</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>277</td>
#       <td>316</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>317</td>
#       <td>368</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>369</td>
#       <td>421</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>422</td>
#       <td>468</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>469</td>
#       <td>520</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>521</td>
#       <td>572</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>573</td>
#       <td>625</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>626</td>
#       <td>659</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>660</td>
#       <td>707</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>708</td>
#       <td>756</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>757</td>
#       <td>803</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>804</td>
#       <td>852</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>853</td>
#       <td>897</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>898</td>
#       <td>946</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>947</td>
#       <td>--</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dict1=[{'Diferença':'84'},{'Diferença':'34'},{'Diferença':'40'},{'Diferença':'51'},{'Diferença':'64'},{'Diferença':'39'},
       {'Diferença':'51'},{'Diferença':'52'},{'Diferença':'46'},{'Diferença':'51'},{'Diferença':'51'},{'Diferença':'52'},
       {'Diferença':'33'},{'Diferença':'47'},{'Diferença':'48'},{'Diferença':'46'},{'Diferença':'48'},{'Diferença':'44'},
       {'Diferença':'48'},{'Diferença':'--'}]
df1=pd.DataFrame(dict1)
df1[['Diferença']]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Diferença</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>84</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>--</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1['Diferença'].max()
# Out:
# '84'

# %%
df.ix[0]
# Out:
# Geração                    Primeira
# Primeiro Episódio               000
# Região                        Kanto
# Série                Série Original
# Temporada               Liga Índigo
# Último Episódio                 083
# Name: 0, dtype: object

# %%
series=[{'Série':'Série Original' , 'Quantidade de temporadas':'5'},
        {'Série':'Geração Avançada' , 'Quantidade de temporadas':'4'},
        {'Série':'Diamante e Pérola' , 'Quantidade de temporadas':'4'},
        {'Série':'Preto e Branco' , 'Quantidade de temporadas':'3'},
        {'Série':'XY' , 'Quantidade de temporadas':'3'},
        {'Série': 'Sun and Moon' , 'Quantidade de temporadas':'1'}]
df3=pd.DataFrame(series)
df3[['Série' , 'Quantidade de temporadas']]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Série</th>
#       <th>Quantidade de temporadas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Série Original</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Geração Avançada</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Diamante e Pérola</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Preto e Branco</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>XY</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Sun and Moon</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Exercício 6
# - Passo 1: Gere um arquivo com 10 notas de cinco alunos (Deve conter o nome do aluno e as notas).
# - Passo 2: Em seguida crie uma array em numpy com essas notas.
# - Passo 3: Crie um DataFrame dessas notas.
# - Passo 4: Identifique qual menor nota e quem foi o aluno que obteve essa nota
# - Passo 5: Identifique o aluno que tirou as melhores notas.

# %%
# %%writefile notas.txt
# Ney 10, 10
# Out:
# Overwriting notas.txt

# %%
Alunos=[{'Nome':'Carlos' , 'Nota 1':'9.9', 'Nota 2':'9.9'},
       {'Nome':'André' , 'Nota 1':'1', 'Nota 2':'2'}, 
       {'Nome':'Paulo', 'Nota 1':'8', 'Nota 2':'7.5'},
       {'Nome':'Gustavo' , 'Nota 1':'9', 'Nota 2':'9.5'},
       {'Nome':'Daniela' , 'Nota 1':'2', 'Nota 2':'6'}]
AlunosM=[['Carlos' , '9.9', '9.9'],
       ['André' , '5', '7'], 
       ['Paulo', '8', '7.5'],
       ['Gustavo' , '9', '9.5'],
       ['Daniela' , '2', '6']]

# %%
import numpy as np

# %%
import pandas as pd

# %%
matriz=np.array(AlunosM)

# %%
matriz
# Out:
# array([['Carlos', '9.9', '9.9'],
#        ['André', '5', '7'],
#        ['Paulo', '8', '7.5'],
#        ['Gustavo', '9', '9.5'],
#        ['Daniela', '2', '6']],
#       dtype='<U7')

# %%
df22=pd.DataFrame(Alunos)
df22[['Nome' , 'Nota 1' , 'Nota 2']]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nome</th>
#       <th>Nota 1</th>
#       <th>Nota 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Carlos</td>
#       <td>9.9</td>
#       <td>9.9</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>André</td>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Paulo</td>
#       <td>8</td>
#       <td>7.5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Gustavo</td>
#       <td>9</td>
#       <td>9.5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Daniela</td>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df22.min()
# Out:
# Nome      André
# Nota 1        1
# Nota 2        2
# dtype: object

# %% [markdown]
# #### Exercicio 7
# - O Jogo da Vida (The Game of Life) é um autômato celular (cellular automaton) introduzido por John Horton Conway em 1970. Um automato celular consiste de uma rede de células. Cada célula pode estar em um número finito de estados, como morta ou viva. O “jogo” é na verdade uma simulação que permite observar a evolução de um processo a partir de uma certa condição inicial.
# - O jogo se desenvolve sobre uma matriz bi-dimensional que pode ser tão grande quanto se queira. Vamos chamar essa matriz de mapa. Cada posição ou célula do mapa pode estar vazia (= célula morta) ou ocupada por um agente (= célula viva). Cada posição possui também até 8 posições vizinhas: imediatamente acima, abaixo, aos lados e nas diagonais. Em um determinado instante, o mapa contém uma geração de agentes. A geração no instante seguinte é determinada segundo as regras abaixo:
# - Novos agentes nascem em células vazias que possuam exatamente 3 agentes vizinhos;
# - **Agentes com 2 ou 3 agentes vizinhos sobrevivem;**
# - **Agentes com menos de 2 agentes vizinhos morrem for falta de recursos;**
# - **Agentes com mais de 3 agentes vizinhos morrem por excesso de competição.**
