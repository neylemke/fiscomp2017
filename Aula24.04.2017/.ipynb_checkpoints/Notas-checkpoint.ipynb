# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
import pandas as pd

# %%
df2=pd.read_csv("FisicaComputacional2017.csv",skiprows=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3f64967b74b3> in <module>()
# ----> 1 df2=pd.read_csv("FisicaComputacional2017.csv",skiprows=2)
#
# ...

# %%
df2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-008b2f7b169b> in <module>()
# ----> 1 df2.columns
#
# NameError: name 'df2' is not defined

# %%
df2.columns=[u'Name', u'Email', u'Aula03.04.2017', u'Aula06.03.2017',
       u'Aula10.04.2017', u'Aula13.03.2017', u'Aula17.04.2017', u'Aula20.03.2017',
       u'Aula24.04.2017', u'Aula27.03.2017']

# %%
coldates=[name[4:] for name in df2.columns[2:]]
df2.columns=list(df2.columns[0:2])+coldates

# %%
def orddate(data):
    return int(data[0:2])+int(data[3:5]*100)

# %%
sortedcol=sorted(coldates,key=orddate)

# %%
df2[list(df2.columns[0:2])+sortedcol]
# Out:
#                         Name                                   Email  \
# 0                Amanda Rosa                     arosa0211@gmail.com
# 1               Amanda Sasse         amanda_sasse@aluno.ibb.unesp.br
# 2                Andre Silva                   afs090996@hotmail.com
# 3                Caio Garcia           caio_garcia_souza@hotmail.com
# 4               Carlos Natal          crnjunior93@aluno.ibb.unesp.br
# 5                     Carol                 caarolpiovesan@gmail.com
# 6                Diogo Godoi                     godoi-dh@bol.com.br
# 7              Eduardasilva     eduarda.pio.costa@aluno.ibb.unesp.br
# 8               Felipe Breve          brevefelipe@aluno.ibb.unesp.br
# 9              Felipe Chimin            flpchimin@aluno.ibb.unesp.br
# 10            Gabriel Arruda         gabrielaugusto.arruda@gmail.com
# 11         Gabriel de Castro            gabriel.lic.fisica@gmail.com
# 12  Gustavo Henrique Tomanik                     gutomanik@gmail.com
# ...

# %%
from ipy_table import *
import numpy as np

# %%
values=df2.values

# %%
notas = np.vstack([df2.columns,values ])

# %%
make_table(notas, interactive=False)
apply_theme('basic')
set_column_style(0, color='lightBlue',align='left')
set_column_style(1,width=150,align='center')
set_row_style(0, color='lightblue',thick_border='top,bottom',bold=True,align='center')

# %%
strtable=render()._repr_html_()

# %%
f=open('table.html','w')
f.write(strtable)
f.close()

# %%
# !pandoc -s table.html -o table.pdf

# %%
! pwd
# Out:
# /Users/neylemke/tex/ensino/fiscomppython/fiscomp2017
