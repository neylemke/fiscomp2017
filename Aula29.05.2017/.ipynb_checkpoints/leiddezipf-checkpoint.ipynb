# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file=open("lusiadas.txt","r")

# %%
texto=file.readlines()

# %%
dict={}
for line in texto:
    for word in line.split():
        word2=word.upper()
        word=word2.strip(".,;!?")
        if word2 in dict:
            dict[word2]=dict[word2]+1
        else:
            dict[word2]=1

# %%
oco=list(dict.values())
oco.sort()
oco.reverse()
X=np.array(range(len(oco)))+1
Y=np.array(oco)

# %%
fig = plt.figure(figsize=(10,10)) # define plot area
ax = fig.gca() # define axis    
x = fig.gca() # define eixo               
plt.plot(X,Y)
ax.set_title('Frequencia de Palavras das Lusiadas') # Título Principal
ax.set_xlabel('rank') # Eixo x
ax.set_ylabel('Freq')# Eixo y

# %%
logx=np.log(X)
logy=np.log(Y)
fig = plt.figure(figsize=(10,10)) # define plot area
ax = fig.gca() # define axis    
x = fig.gca() # define eixo               
plt.plot(logx,logy)
ax.set_title('Frequencia de Palavras das Lusiadas') # Título Principal
ax.set_xlabel('rank') # Eixo x
ax.set_ylabel('Freq')# Eixo y

# %%
from collections import OrderedDict
from operator import itemgetter    

OrderedDict(sorted(dict.items(), key=itemgetter(1), reverse=True))
# Out:
# OrderedDict([('QUE', 2612),
#              ('E', 2117),
#              ('O', 1869),
#              ('A', 1837),
#              ('DE', 1420),
#              ('SE', 822),
#              ('OS', 718),
#              ('DO', 621),
#              ('COM', 562),
#              ('NÃO', 546),
#              ('POR', 534),
#              ('EM', 515),
#              ('AS', 509),
#              ('DA', 484),
#              ('LHE', 324),
#              ('NO', 319),
#              ('JÁ', 286),
#              ('MAIS', 258),
#              ('NA', 250),
#              ('AO', 231),
#              ('DOS', 226),
#              ('QUEM', 221),
#              ('MAS', 220),
#              ('UM', 219),
#              ('TÃO', 208),
#              ('PARA', 204),
#              ('COMO', 186),
#              ('THE', 173),
#              ('ONDE', 173),
#              ('TERRA', 169),
#              ('GENTE', 165),
#              ('SEU', 151),
#              ('MAR', 150),
#              ('REI', 150),
#              ('DAS', 147),
#              ('É', 146),
#              ('NOS', 141),
#              ('GRANDE', 125),
#              ('OF', 119),
#              ('OU', 119),
#              ('TANTO', 117),
#              ('FOI', 115),
#              ('SEM', 111),
#              ('À', 111),
#              ('SÓ', 111),
#              ('QUE,', 108),
#              ('TEM', 101),
#              ('SEUS', 101),
#              ('QUANDO', 99),
#              ('ALI', 91),
#              ('ASSIM', 89),
#              ('BEM', 88),
#              ('ME', 86),
#              ('NEM', 83),
#              ('PORQUE', 83),
#              ('PROJECT', 82),
#              ('NAS', 80),
#              ('TO', 80),
#              ('MUNDO', 79),
#              ('SER', 79),
#              ('SEMPRE', 78),
#              ('TODA', 77),
#              ('TUDO', 77),
#              ('REINO', 76),
#              ('CONTRA', 75),
#              ('OR', 75),
#              ('NUNCA', 72),
#              ('TODO', 70),
#              ('ESTÁ', 70),
#              ('VÃO', 70),
#              ('AND', 69),
#              ('YOU', 68),
#              ('TE', 68),
#              ('NOME', 67),
#              ('CÉU', 66),
#              ('FORTE', 65),
#              ('TEMPO', 65),
#              ('ENTRE', 65),
#              ('AQUI', 65),
#              ('OUTRO', 65),
#              ('QUAL', 64),
#              ('SÃO', 64),
#              ('TAMBÉM', 62),
#              ('LÁ', 61),
#              ('AOS', 59),
#              ('ESTE', 58),
#              ('PEITO', 58),
#              ('TODOS', 57),
#              ('MUITO', 57),
#              ('IN', 56),
#              ('VAI', 56),
#              ('SUA', 56),
#              ("CO'O", 55),
#              ('ESTA', 55),
#              ('GUTENBERG-TM', 54),
#              ('FAZ', 54),
#              ('PELA', 54),
#              ('LOGO', 54),
#              ('EU', 54),
#              ('VER', 53),
#              ('Ó', 52),
#              ('MAL', 52),
#              ('OUTROS', 52),
#              ('QUANTO', 51),
#              ('AMOR', 51),
#              ('DEPOIS', 51),
#              ('PELO', 50),
#              ('"E', 50),
#              ('UMA', 50),
#              ('ELE', 50),
#              ('FAMA', 49),
#              ('POUCO', 49),
#              ('TAL', 49),
#              ('POIS', 48),
#              ('AGORA', 48),
#              ('REI,', 48),
#              ('PARTE', 47),
#              ('WITH', 47),
#              ('THIS', 47),
#              ('ARMAS', 46),
#              ('ÁGUAS', 44),
#              ('ÀS', 44),
#              ('TERRAS', 44),
#              ('TER', 43),
#              ('VOS', 43),
#              ('DESTA', 43),
#              ('ERA', 43),
#              ('FORÇA', 42),
#              ('FILHO', 42),
#              ('DEUS', 42),
#              ('GENTES', 42),
#              ('TINHA', 42),
#              ('ONDAS', 41),
#              ('TERRA,', 41),
#              ('VÊ', 41),
#              ('ENFIM', 41),
#              ('CLARO', 40),
#              ('OLHOS', 39),
#              ('GRANDES', 39),
#              ('FEZ', 39),
#              ('VENDO', 38),
#              ('MIL', 38),
#              ('GENTE,', 38),
#              ('VIDA', 38),
#              ('ÁGUA', 38),
#              ('MOUROS', 37),
#              ('MAR,', 37),
#              ('"MAS', 37),
#              ('MENOS', 37),
#              ('POVO', 36),
#              ('NENHUM', 36),
#              ('MANDA', 36),
#              ('FOR', 36),
#              ('VÓS', 36),
#              ('PERA', 35),
#              ('ANY', 35),
#              ('ESTAVA', 35),
#              ('CAPITÃO', 34),
#              ('MORTE', 34),
#              ('PODER', 34),
#              ('PODE', 34),
#              ('HÁ', 34),
#              ('LONGE', 33),
#              ('ILHA', 33),
#              ('SI', 33),
#              ('WORK', 33),
#              ('OUTRAS', 33),
#              ('VEM', 33),
#              ('DAR', 33),
#              ('SOBRE', 33),
#              ('CIDADE', 33),
#              ('VISTA', 33),
#              ('ILUSTRE', 33),
#              ('ESTÃO', 32),
#              ('NOBRE', 32),
#              ('ALTA', 32),
#              ('TU,', 32),
#              ('MOURO', 32),
#              ('FEITOS', 32),
#              ('DOCE', 31),
#              ('CUJA', 31),
#              ('OUTRA', 31),
#              ('PALAVRAS', 31),
#              ('ISTO', 31),
#              ('NAUS', 31),
#              ('FOGO', 31),
#              ('COSTA', 30),
#              ('ALTO', 30),
#              ('CO', 30),
#              ('DONDE', 30),
#              ('PELAS', 30),
#              ('VENTO', 30),
#              ('NESTE', 30),
#              ('VÊM', 30),
#              ('SERÁ', 30),
#              ('ESFORÇO', 30),
#              ('INDA', 29),
#              ('DELE', 29),
#              ('GAMA', 29),
#              ('ALGUM', 29),
#              ('TÊM', 29),
#              ('ENQUANTO', 28),
#              ('SANGUE', 28),
#              ('VÁRIAS', 28),
#              ('FORA', 28),
#              ('DURO', 28),
#              ('DESTE', 28),
#              ('TU', 27),
#              ('AINDA', 27),
#              ('SOL', 27),
#              ('NUM', 27),
#              ('ANTES', 27),
#              ('AQUELE', 27),
#              ('IS', 27),
#              ('LEI', 27),
#              ('ELECTRONIC', 27),
#              ('FORAM', 27),
#              ('CAMPO', 27),
#              ('SEGUNDO', 27),
#              ('GESTO', 27),
#              ('PÁTRIA', 27),
#              ('"NÃO', 26),
#              ('GLÓRIA', 26),
#              ('DÁ', 26),
#              ('PRIMEIRO', 26),
#              ('PELOS', 26),
#              ('CERTO', 26),
#              ('VEZES', 26),
#              ('TANTA', 26),
#              ('SENDO', 25),
#              ('ELA', 25),
#              ('MUI', 25),
#              ('E,', 25),
#              ('DUM', 25),
#              ('ATÉ', 24),
#              ('GUTENBERG', 24),
#              ('LUZ', 24),
#              ('ESTAS', 24),
#              ('FAZER', 24),
#              ('ARTE', 24),
#              ('VÓS,', 24),
#              ('NOVO', 24),
#              ('GUERRA', 23),
#              ('GRÃO', 23),
#              ('NÓS', 23),
#              ('OBRAS', 23),
#              ('VOZ', 23),
#              ('VENTOS', 23),
#              ('TEU', 23),
#              ('JUNTO', 23),
#              ('PARTES', 22),
#              ('SANTA', 22),
#              ('CAMINHO', 22),
#              ('OLHA', 22),
#              ('ESTES', 22),
#              ('MAS,', 22),
#              ('ENTÃO', 22),
#              ('DIANTE', 22),
#              ('DURA', 22),
#              ('MUITOS', 22),
#              ('SUAS', 22),
#              ('DEUSES', 22),
#              ('WORKS', 22),
#              ('BY', 22),
#              ('CORPO', 21),
#              ('TRABALHOS', 21),
#              ("CO'OS", 21),
#              ('REIS', 21),
#              ('MARES', 21),
#              ('MÃO', 21),
#              ('FIM', 21),
#              ('FORMOSA', 21),
#              ('TERMS', 21),
#              ('TRAZ', 21),
#              ('COR', 21),
#              ('FILHOS', 21),
#              ('NOT', 21),
#              ('LARGO', 21),
#              ('"OLHA', 21),
#              ('DIA', 21),
#              ('POSTO', 21),
#              ('AR', 20),
#              ('CUJO', 20),
#              ('IR', 20),
#              ('TI', 20),
#              ('CAMPOS', 20),
#              ('QUIS', 20),
#              ('TANTAS', 20),
#              ('SOMENTE', 20),
#              ('OURO', 20),
#              ('CAPITÃO,', 20),
#              ('VOSSO', 20),
#              ('VÊS', 20),
#              ('TANTOS', 19),
#              ('LONGO', 19),
#              ('VÁRIOS', 19),
#              ('ÍNDIA', 19),
#              ('VEREIS', 19),
#              ('ALTOS', 19),
#              ('UNS', 19),
#              ('TEMOR', 19),
#              ('ENFIM,', 19),
#              ('CORAÇÃO', 19),
#              ('BE', 19),
#              ('TAIS', 19),
#              ('PORTO', 19),
#              ('ARE', 19),
#              ('QUASE', 19),
#              ('VIU', 19),
#              ('COA', 19),
#              ('ERAM', 19),
#              ('IF', 19),
#              ('NOVA', 19),
#              ('FAZEM', 19),
#              ('FARÁ', 19),
#              ('TEJO', 18),
#              ('MOSTRA', 18),
#              ('RIO', 18),
#              ('MAIS,', 18),
#              ('MONTES', 18),
#              ('PEITOS', 18),
#              ('DANDO', 18),
#              ('SABE', 18),
#              ('MÃOS', 18),
#              ('PARECE', 18),
#              ('LÁGRIMAS', 18),
#              ('BUSCAR', 18),
#              ('ALGUNS', 18),
#              ('PARTE,', 18),
#              ('GENTIO', 18),
#              ('BRAÇO', 18),
#              ('ARMADA', 18),
#              ('ALL', 18),
#              ('CANTO', 18),
#              ('MEUS', 17),
#              ('FAZENDO', 17),
#              ('TODAS', 17),
#              ('MEU', 17),
#              ('FORTUNA', 17),
#              ('ELES', 17),
#              ('POUCA', 17),
#              ('SANTO', 17),
#              ('CASO', 17),
#              ('FERRO', 17),
#              ('ROSTO', 17),
#              ('PORÉM', 17),
#              ('FORÇAS', 17),
#              ('NESTA', 17),
#              ('FORTES', 17),
#              ('CADA', 17),
#              ('LEVA', 17),
#              ('TRABALHO', 17),
#              ('GRÃ', 17),
#              ('ANTIGO', 17),
#              ('TENS', 17),
#              ('INIMIGOS', 17),
#              ('CLARA', 16),
#              ('PADRE', 16),
#              ('NOVAS', 16),
#              ('MÃE', 16),
#              ('DEUSA', 16),
#              ('QUER', 16),
#              ('ARDENTE,', 16),
#              ('LEVE', 16),
#              ('FERO', 16),
#              ('NELA', 16),
#              ('MUNDO,', 16),
#              ('ESTRANHA', 16),
#              ('ORA', 16),
#              ('VOSSOS', 16),
#              ('DOIS', 16),
#              ('NOITE', 15),
#              ('THAT', 15),
#              ('MINHA', 15),
#              ('TOMAR', 15),
#              ('DOM', 15),
#              ('HUMANO', 15),
#              ('MOURO,', 15),
#              ('SOBERBA', 15),
#              ('MAY', 15),
#              ('PAI', 15),
#              ('MEDO', 15),
#              ('COMPANHIA', 15),
#              ('QUALQUER', 15),
#              ('PEITO,', 15),
#              ('CÉUS', 15),
#              ('RICA', 15),
#              ('TRÊS', 15),
#              ('ANTIGA', 15),
#              ('VIL', 15),
#              ('GAMA,', 15),
#              ('AT', 15),
#              ('FIRME', 15),
#              ('CRISTO', 15),
#              ('"JÁ', 15),
#              ('VELHO', 15),
#              ('TEVE', 15),
#              ('FOSSE', 15),
#              ('SOBERBO', 15),
#              ('BACO', 15),
#              ('FALSO', 15),
#              ('SUBLIME', 15),
#              ('VIR', 15),
#              ('TRISTE', 14),
#              ('DIZ', 14),
#              ('SINAL', 14),
#              ('SENÃO', 14),
#              ('FROTA', 14),
#              ('SEJA', 14),
#              ('RAZÃO', 14),
#              ('GENTE.', 14),
#              ('DEIXA', 14),
#              ('ARDENTE', 14),
#              ('LARGA', 14),
#              ('VOSSA', 14),
#              ('FROM', 14),
#              ('DÃO', 14),
#              ('DONATIONS', 14),
#              ('CÉU,', 14),
#              ('FOUNDATION', 14),
#              ('TORNA', 14),
#              ('SÓS', 14),
#              ('OTHER', 14),
#              ('DESEJO', 14),
#              ('DAQUI', 14),
#              ('CABO', 14),
#              ('NINFAS', 13),
#              ('COPYRIGHT', 13),
#              ('DISSE', 13),
#              ('NISTO', 13),
#              ('SORTE', 13),
#              ('FAVOR', 13),
#              ('GUERRA,', 13),
#              ('ARCHIVE', 13),
#              ('DIVINA', 13),
#              ('AFONSO', 13),
#              ('REINOS', 13),
#              ('ETERNA', 13),
#              ('EXÉRCITO', 13),
#              ('VIRTUDE', 13),
#              ('MEMÓRIA', 13),
#              ('VELAS', 13),
#              ('DESPOIS', 13),
#              ('DEIXANDO', 13),
#              ('USE', 13),
#              ('VITÓRIA', 13),
#              ('LITERARY', 13),
#              ('FULL', 13),
#              ('FERA', 13),
#              ('MANEIRA', 13),
#              ('DIA,', 13),
#              ('MOÇO', 13),
#              ('FICA', 13),
#              ('DISSE,', 13),
#              ('MUITAS', 13),
#              ('ARMADA,', 13),
#              ('PÔR', 13),
#              ('CABEÇA', 13),
#              ('VALOR', 13),
#              ('TERRENO', 13),
#              ('FALTA', 13),
#              ('MONTE', 13),
#              ('DESTES', 13),
#              ('NOVOS', 13),
#              ('LEDO', 13),
#              ('NOSSOS', 12),
#              ('MUROS', 12),
#              ('PILOTO', 12),
#              ('TANTO,', 12),
#              ('DEUS,', 12),
#              ('FORÇA,', 12),
#              ('LUSO', 12),
#              ('"A', 12),
#              ('CAVALEIRO,', 12),
#              ('INDO', 12),
#              ('SÚBITO', 12),
#              ('PORTUGUÊS', 12),
#              ('COUSAS', 12),
#              ('ESTAR', 12),
#              ('AFONSO,', 12),
#              ('IT', 12),
#              ('ENGANO', 12),
#              ('JUGO', 12),
#              ('POUCOS', 12),
#              ('AQUELES', 12),
#              ('PERIGOS', 12),
#              ('3', 12),
#              ('BELA', 12),
#              ('GUERRAS', 12),
#              ('FUROR', 12),
#              ('NAU', 12),
#              ('CASA', 12),
#              ('LUSITANO,', 12),
#              ('IRA', 12),
#              ('CORTANDO', 12),
#              ('"EIS', 12),
#              ('CASOS', 12),
#              ('"Ó', 12),
#              ('MELHOR', 12),
#              ('PASSAR', 12),
#              ('FÚRIA', 12),
#              ('F', 12),
#              ('VÉNUS', 12),
#              ('FORTE,', 12),
#              ('CONSIGO', 12),
#              ('ESTE,', 12),
#              ('BRAVO', 12),
#              ('QUAIS', 12),
#              ('VENTURA', 12),
#              ('ANDAVA', 12),
#              ('INIMIGO', 12),
#              ('CÁ', 12),
#              ('SOL,', 12),
#              ('ESCURA', 12),
#              ('FILHO,', 12),
#              ('BÁRBARO', 11),
#              ('ESPERANÇA', 11),
#              ('ÁFRICA', 11),
#              ('MAIOR', 11),
#              ('VINHA', 11),
#              ('4', 11),
#              ('LICENSE', 11),
#              ('BRAÇOS', 11),
#              ('PARAGRAPH', 11),
#              ('PAZ', 11),
#              ('SABER', 11),
#              ('AQUELA', 11),
#              ('ON', 11),
#              ('"COM', 11),
#              ('ESTRELAS', 11),
#              ('TERÁ', 11),
#              ('MEIO', 11),
#              ('30', 11),
#              ('FRACO', 11),
#              ('PORQUE,', 11),
#              ('VONTADE', 11),
#              ('NEGRO', 11),
#              ('ALTAS', 11),
#              ('CIMA', 11),
#              ('PASSA', 11),
#              ('CAUSA', 11),
#              ('SETAS', 11),
#              ('60', 11),
#              ('SENHOR', 11),
#              ('ENGENHO', 11),
#              ('LANÇA', 11),
#              ('É,', 11),
#              ('ASSI', 11),
#              ('PÕE', 11),
#              ('NADA', 11),
#              ('ALEGRE', 11),
#              ('90', 11),
#              ('TEUS', 11),
#              ('ANTIGOS', 11),
#              ('SONO', 11),
#              ('VIDA,', 11),
#              ('50', 11),
#              ('NELE', 11),
#              ('22', 11),
#              ('COUSA', 11),
#              ('BATÉIS', 11),
#              ('PÓLO', 11),
#              ('NOBRES', 11),
#              ('PRAIAS', 11),
#              ('PORTUGUESES', 11),
#              ('PRÉMIO', 11),
#              ('IMPÉRIO', 11),
#              ('VERDADE,', 11),
#              ('ISSO', 11),
#              ('FRIO', 11),
#              ('FILHA', 11),
#              ('TAMBÉM,', 11),
#              ('DOUS', 11),
#              ('48', 10),
#              ('79', 10),
#              ('ENTRA', 10),
#              ('41', 10),
#              ('12', 10),
#              ('34', 10),
#              ('9', 10),
#              ('59', 10),
#              ('LEIS', 10),
#              ('DELES', 10),
#              ('46', 10),
#              ('65', 10),
#              ('61', 10),
#              ('SEGURO', 10),
#              ('23', 10),
#              ('6', 10),
#              ('FAMOSO', 10),
#              ('MÁ', 10),
#              ('40', 10),
#              ('GERAÇÃO', 10),
#              ('63', 10),
#              ('CAN', 10),
#              ('ANOS', 10),
#              ('58', 10),
#              ('DAQUELA', 10),
#              ('FADO', 10),
#              ('26', 10),
#              ('80', 10),
#              ('81', 10),
#              ('VIA', 10),
#              ('FUNDO', 10),
#              ('66', 10),
#              ('COLO', 10),
#              ('29', 10),
#              ('JUSTA', 10),
#              ('NINGUÉM', 10),
#              ('MORTOS', 10),
#              ('31', 10),
#              ('LUSITANO', 10),
#              ('56', 10),
#              ('ÂNIMO', 10),
#              ('BOM', 10),
#              ('SÁBIO', 10),
#              ('17', 10),
#              ('70', 10),
#              ('"QUE', 10),
#              ('24', 10),
#              ('38', 10),
#              ('54', 10),
#              ('VENTO,', 10),
#              ('DANO,', 10),
#              ('ENGANO,', 10),
#              ('82', 10),
#              ('5', 10),
#              ('73', 10),
#              ('PRIMEIRA', 10),
#              ('7', 10),
#              ('53', 10),
#              ('DOZE', 10),
#              ('TUA', 10),
#              ('HOMENS', 10),
#              ('43', 10),
#              ('DESSE', 10),
#              ('77', 10),
#              ('78', 10),
#              ('ACCESS', 10),
#              ('VERDADE', 10),
#              ('52', 10),
#              ('45', 10),
#              ('FRONTE', 10),
#              ('44', 10),
#              ('71', 10),
#              ('13', 10),
#              ('DEBAIXO', 10),
#              ('ELE,', 10),
#              ('COS', 10),
#              ('UNITED', 10),
#              ('68', 10),
#              ('BUSCANDO', 10),
#              ('39', 10),
#              ('19', 10),
#              ('57', 10),
#              ('86', 10),
#              ('SOIS', 10),
#              ('11', 10),
#              ('51', 10),
#              ('62', 10),
#              ('75', 10),
#              ('JUÍZO', 10),
#              ('83', 10),
#              ('85', 10),
#              ('84', 10),
#              ('8', 10),
#              ('74', 10),
#              ('64', 10),
#              ('CIDADES', 10),
#              ('25', 10),
#              ('49', 10),
#              ('ALMAS', 10),
#              ('15', 10),
#              ('28', 10),
#              ('18', 10),
#              ('36', 10),
#              ('27', 10),
#              ('47', 10),
#              ('PERIGO', 10),
#              ('72', 10),
#              ('NAUS,', 10),
#              ('42', 10),
#              ('16', 10),
#              ('1', 10),
#              ('32', 10),
#              ('TORPE', 10),
#              ('69', 10),
#              ('10', 10),
#              ('VÊ,', 10),
#              ('87', 10),
#              ('35', 10),
#              ('DAMAS', 10),
#              ('LONGOS', 10),
#              ('IRADO,', 10),
#              ('2', 10),
#              ('37', 10),
#              ('20', 10),
#              ('55', 10),
#              ('76', 10),
#              ('33', 10),
#              ('ÍNDIA,', 10),
#              ('NOSSA', 10),
#              ('CONSELHO', 10),
#              ('67', 10),
#              ('RAIOS', 10),
#              ('14', 10),
#              ('PÔS', 10),
#              ('REMÉDIO', 9),
#              ('TODOS,', 9),
#              ('PASSO', 9),
#              ('FAMOSA', 9),
#              ('PRÍNCIPE', 9),
#              ('FROTA,', 9),
#              ('NOSSO', 9),
#              ('ESTANDO', 9),
#              ('POSSA', 9),
#              ('HUMANA', 9),
#              ('ILUSTRES', 9),
#              ('NÃO,', 9),
#              ('DEU', 9),
#              ('TAMANHO', 9),
#              ('HONRAS', 9),
#              ('TOMOU', 9),
#              ('PUBLIC', 9),
#              ('VITÓRIAS', 9),
#              ('FORA,', 9),
#              ('95', 9),
#              ('PERTO', 9),
#              ('PURO', 9),
#              ('GRANDE,', 9),
#              ('AONDE', 9),
#              ('SERRA', 9),
#              ('PROFUNDO,', 9),
#              ('DUROS', 9),
#              ('REINO,', 9),
#              ('OCEANO,', 9),
#              ('VEIO', 9),
#              ('PRESA', 9),
#              ('RAZÕES', 9),
#              ('WE', 9),
#              ('PRAIA', 9),
#              ('ESTAVAM', 9),
#              ('AGREEMENT', 9),
#              ('FICOU', 9),
#              ('SÓ,', 9),
#              ('EIS', 9),
#              ('DIZ-LHE', 9),
#              ('PAI,', 9),
#              ('TENDO', 9),
#              ('ESPADA', 9),
#              ('FEITO', 9),
#              ('CORRENDO', 9),
#              ('AGREE', 9),
#              ('ASSENTO', 9),
#              ('94', 9),
#              ('COR,', 9),
#              ('AQUI,', 9),
#              ('SUA,', 9),
#              ('FRACA', 9),
#              ('JÚPITER', 9),
#              ('VÃO,', 9),
#              ('91', 9),
#              ('ALMA', 9),
#              ('EBOOK', 9),
#              ('MANCEBO', 9),
#              ('FAMA,', 9),
#              ('QUANTOS', 9),
#              ('LONGA', 9),
#              ('LUSITANA,', 9),
#              ('21', 9),
#              ('89', 9),
#              ('YOUR', 9),
#              ('88', 9),
#              ('PREÇO', 9),
#              ('COISAS', 9),
#              ('MODO', 9),
#              ('DEUSES,', 9),
#              ('BELA,', 9),
#              ('TENHO', 9),
#              ('AJUDA', 9),
#              ('AVANTE', 9),
#              ('ANIMAIS', 9),
#              ('GRANDES,', 9),
#              ('RICO', 9),
#              ('LÍNGUA', 9),
#              ('MAURA', 9),
#              ('93', 9),
#              ('HUMANO,', 9),
#              ('CHAMA', 9),
#              ('PERIGOS,', 9),
#              ('LINDA', 9),
#              ('"SE', 9),
#              ('ALGUMA', 9),
#              ('CIDADE,', 9),
#              ('MUST', 9),
#              ('ARMAS,', 9),
#              ('SERENO', 9),
#              ('COMEÇA', 9),
#              ('MANHA', 9),
#              ('ESPÍRITO', 9),
#              ('FÉ', 9),
#              ('92', 9),
#              ('SOM', 9),
#              ('USADO', 9),
#              ('MORTE,', 9),
#              ('ALEGRIA,', 8),
#              ('DESEJADA', 8),
#              ('DOMAIN', 8),
#              ('COPY', 8),
#              ('POSTA', 8),
#              ('WITHOUT', 8),
#              ('MOSTRAS', 8),
#              ('ÁSPEROS', 8),
#              ('98', 8),
#              ('ABOUT', 8),
#              ('MARTE', 8),
#              ('PODER,', 8),
#              ('"QUAL', 8),
#              ('CULPA', 8),
#              ('VIRÁ', 8),
#              ('AMA,', 8),
#              ('LEDA', 8),
#              ('OURO,', 8),
#              ('"O', 8),
#              ('AJUNTA', 8),
#              ('RAMO', 8),
#              ('RESPONDE', 8),
#              ('OBRIGA', 8),
#              ('PALMA', 8),
#              ('IDADE,', 8),
#              ('CORES', 8),
#              ('SUBTIL', 8),
#              ('ARTE,', 8),
#              ('VERSOS', 8),
#              ('ETERNO', 8),
#              ('PENSAMENTO', 8),
#              ('GOLPES', 8),
#              ('BOCA', 8),
#              ('VINGANÇA', 8),
#              ('COBIÇA', 8),
#              ('NEGRA', 8),
#              ('VENCER', 8),
#              ('99', 8),
#              ('SET', 8),
#              ('POVOS', 8),
#              ('DALI', 8),
#              ('PESO', 8),
#              ('ANDA', 8),
#              ('DENTRO', 8),
#              ('TRAZIA', 8),
#              ('"ESTE', 8),
#              ('VEJA', 8),
#              ('NUMA', 8),
#              ('FEE', 8),
#              ('VOSSAS', 8),
#              ('FEROS', 8),
#              ('USANÇA', 8),
#              ('SUSTENTAR', 8),
#              ('NOMES', 8),
#              ('INIMIGA', 8),
#              ('ESPERA', 8),
#              ('FAZENDA', 8),
#              ('JUSTO', 8),
#              ('96', 8),
#              ('JEITO', 8),
#              ('OCEANO', 8),
#              ('PROA', 8),
#              ('HORRENDO', 8),
#              ("C'UM", 8),
#              ('MEMBROS', 8),
#              ('"ESTA', 8),
#              ('(QUE', 8),
#              ('VINHAM', 8),
#              ('VENCEDOR', 8),
#              ('ALEGRES', 8),
#              ('DIVERSOS', 8),
#              ('MULTIDÃO', 8),
#              ('DOUTRA', 8),
#              ('PÉS', 8),
#              ('BRANCA', 8),
#              ('INCLUDING', 8),
#              ('--"Ó', 8),
#              ('LOUVOR', 8),
#              ('ILHA,', 8),
#              ('AVES', 8),
#              ('ILUSTRE,', 8),
#              ('LEVANDO', 8),
#              ('NAQUELE', 8),
#              ('CARNE', 8),
#              ('NINFA', 8),
#              ('MESTRE', 8),
#              ('DIZEM', 8),
#              ('NATURA', 8),
#              ('FOGO,', 8),
#              ('NAÇÕES', 8),
#              ('DIZENDO,', 8),
#              ('MESMO', 8),
#              ('FONTE', 8),
#              ('FILHAS', 8),
#              ('STATES', 8),
#              ('FRIO,', 8),
#              ('ESTREITO', 8),
#              ('FORTH', 8),
#              ('DIZENDO', 8),
#              ('ILHAS', 8),
#              ('EUROPA', 8),
#              ('SEI', 8),
#              ('VIA,', 8),
#              ('OLIMPO', 8),
#              ('CRUEL', 8),
#              ('FOGE', 8),
#              ('ELAS', 8),
#              ('AMOR,', 8),
#              ('HÁ-DE', 8),
#              ('BANDA', 8),
#              ('LUSITANOS', 8),
#              ('"ASSIM', 8),
#              ('SAIR', 8),
#              ('RIO,', 8),
#              ('CORRE', 8),
#              ('97', 8),
#              ('NELAS', 8),
#              ('VI', 8),
#              ('TEMPO,', 8),
#              ('JUNTAMENTE,', 8),
#              ('ESTÁ,', 7),
#              ('CONTA', 7),
#              ('TAIS,', 7),
#              ('MATA', 7),
#              ('BATEL', 7),
#              ('WILL', 7),
#              ('AURORA', 7),
#              ('AQUILO', 7),
#              ('PRÓPRIOS', 7),
#              ('PRÓPRIO', 7),
#              ('DUAS', 7),
#              ('BRUTO', 7),
#              ('CASTELHANO,', 7),
#              ('ORIENTE,', 7),
#              ('AQUELAS', 7),
#              ('DOURO', 7),
#              ('BRUTA', 7),
#              ('SECTION', 7),
#              ('INIMIGOS,', 7),
#              ('ANGÉLICA', 7),
#              ('SOMBRA', 7),
#              ('ENTRANHAS', 7),
#              ('VENTURA,', 7),
#              ('CANTANDO', 7),
#              ('TRATO', 7),
#              ('LOGO,', 7),
#              ('SENHORIO', 7),
#              ('SERVIÇO', 7),
#              ('SEJAM', 7),
#              ('WHICH', 7),
#              ('CONDE', 7),
#              ('AMBOS', 7),
#              ('AJUNTAMENTO', 7),
#              ('CUIDA', 7),
#              ('FARÃO', 7),
#              ('PIEDADE', 7),
#              ('SUMA', 7),
#              ('ASSOCIATED', 7),
#              ('FORMA', 7),
#              ('CINCO', 7),
#              ('ESTAVA,', 7),
#              ('CAVALOS', 7),
#              ('OUTREM', 7),
#              ('PAÇOS', 7),
#              ('BELO', 7),
#              ('-', 7),
#              ('VERÁ', 7),
#              ('PORTAS', 7),
#              ('GENTES,', 7),
#              ('MIM', 7),
#              ('LAWS', 7),
#              ('FALA', 7),
#              ('JUSTIÇA', 7),
#              ('POVO,', 7),
#              ('FICAVA', 7),
#              ('BREVE', 7),
#              ('SUAVE', 7),
#              ('NOUTRA', 7),
#              ('TODA,', 7),
#              ('PORTUGUESA', 7),
#              ('NINFAS,', 7),
#              ('ESTOUTRO', 7),
#              ('ASAS', 7),
#              ('DAQUELES', 7),
#              ('FLAMAS', 7),
#              ('MURO', 7),
#              ('GENTE;', 7),
#              ('CARRO', 7),
#              ('CATUAL', 7),
#              ('IRADO', 7),
#              ('FEBO', 7),
#              ('DIAS', 7),
#              ('DELA.', 7),
#              ('AMADA', 7),
#              ('WORK,', 7),
#              ...])

# %%
lis=list(dict.items())
def getKey(item):
    return item[1]

# %%
sorted(lis,key=itemgetter(1),reverse=True)
# Out:
# [('QUE', 2612),
#  ('E', 2117),
#  ('O', 1869),
#  ('A', 1837),
#  ('DE', 1420),
#  ('SE', 822),
#  ('OS', 718),
#  ('DO', 621),
#  ('COM', 562),
#  ('NÃO', 546),
#  ('POR', 534),
#  ('EM', 515),
#  ('AS', 509),
#  ('DA', 484),
#  ('LHE', 324),
#  ('NO', 319),
#  ('JÁ', 286),
#  ('MAIS', 258),
#  ('NA', 250),
#  ('AO', 231),
#  ('DOS', 226),
#  ('QUEM', 221),
#  ('MAS', 220),
#  ('UM', 219),
#  ('TÃO', 208),
#  ('PARA', 204),
#  ('COMO', 186),
#  ('THE', 173),
#  ('ONDE', 173),
#  ('TERRA', 169),
#  ('GENTE', 165),
#  ('SEU', 151),
#  ('MAR', 150),
#  ('REI', 150),
#  ('DAS', 147),
#  ('É', 146),
#  ('NOS', 141),
#  ('GRANDE', 125),
#  ('OF', 119),
#  ('OU', 119),
#  ('TANTO', 117),
#  ('FOI', 115),
#  ('SEM', 111),
#  ('À', 111),
#  ('SÓ', 111),
#  ('QUE,', 108),
#  ('TEM', 101),
#  ('SEUS', 101),
#  ('QUANDO', 99),
#  ('ALI', 91),
#  ('ASSIM', 89),
#  ('BEM', 88),
#  ('ME', 86),
#  ('NEM', 83),
#  ('PORQUE', 83),
#  ('PROJECT', 82),
#  ('NAS', 80),
#  ('TO', 80),
#  ('MUNDO', 79),
#  ('SER', 79),
#  ('SEMPRE', 78),
#  ('TODA', 77),
#  ('TUDO', 77),
#  ('REINO', 76),
#  ('CONTRA', 75),
#  ('OR', 75),
#  ('NUNCA', 72),
#  ('TODO', 70),
#  ('ESTÁ', 70),
#  ('VÃO', 70),
#  ('AND', 69),
#  ('YOU', 68),
#  ('TE', 68),
#  ('NOME', 67),
#  ('CÉU', 66),
#  ('FORTE', 65),
#  ('TEMPO', 65),
#  ('ENTRE', 65),
#  ('AQUI', 65),
#  ('OUTRO', 65),
#  ('QUAL', 64),
#  ('SÃO', 64),
#  ('TAMBÉM', 62),
#  ('LÁ', 61),
#  ('AOS', 59),
#  ('ESTE', 58),
#  ('PEITO', 58),
#  ('TODOS', 57),
#  ('MUITO', 57),
#  ('IN', 56),
#  ('VAI', 56),
#  ('SUA', 56),
#  ("CO'O", 55),
#  ('ESTA', 55),
#  ('GUTENBERG-TM', 54),
#  ('FAZ', 54),
#  ('PELA', 54),
#  ('LOGO', 54),
#  ('EU', 54),
#  ('VER', 53),
#  ('Ó', 52),
#  ('MAL', 52),
#  ('OUTROS', 52),
#  ('QUANTO', 51),
#  ('AMOR', 51),
#  ('DEPOIS', 51),
#  ('PELO', 50),
#  ('"E', 50),
#  ('UMA', 50),
#  ('ELE', 50),
#  ('FAMA', 49),
#  ('POUCO', 49),
#  ('TAL', 49),
#  ('POIS', 48),
#  ('AGORA', 48),
#  ('REI,', 48),
#  ('PARTE', 47),
#  ('WITH', 47),
#  ('THIS', 47),
#  ('ARMAS', 46),
#  ('ÁGUAS', 44),
#  ('ÀS', 44),
#  ('TERRAS', 44),
#  ('TER', 43),
#  ('VOS', 43),
#  ('DESTA', 43),
#  ('ERA', 43),
#  ('FORÇA', 42),
#  ('FILHO', 42),
#  ('DEUS', 42),
#  ('GENTES', 42),
#  ('TINHA', 42),
#  ('ONDAS', 41),
#  ('TERRA,', 41),
#  ('VÊ', 41),
#  ('ENFIM', 41),
#  ('CLARO', 40),
#  ('OLHOS', 39),
#  ('GRANDES', 39),
#  ('FEZ', 39),
#  ('VENDO', 38),
#  ('MIL', 38),
#  ('GENTE,', 38),
#  ('VIDA', 38),
#  ('ÁGUA', 38),
#  ('MOUROS', 37),
#  ('MAR,', 37),
#  ('"MAS', 37),
#  ('MENOS', 37),
#  ('POVO', 36),
#  ('NENHUM', 36),
#  ('MANDA', 36),
#  ('FOR', 36),
#  ('VÓS', 36),
#  ('PERA', 35),
#  ('ANY', 35),
#  ('ESTAVA', 35),
#  ('CAPITÃO', 34),
#  ('MORTE', 34),
#  ('PODER', 34),
#  ('PODE', 34),
#  ('HÁ', 34),
#  ('LONGE', 33),
#  ('ILHA', 33),
#  ('SI', 33),
#  ('WORK', 33),
#  ('OUTRAS', 33),
#  ('VEM', 33),
#  ('DAR', 33),
#  ('SOBRE', 33),
#  ('CIDADE', 33),
#  ('VISTA', 33),
#  ('ILUSTRE', 33),
#  ('ESTÃO', 32),
#  ('NOBRE', 32),
#  ('ALTA', 32),
#  ('TU,', 32),
#  ('MOURO', 32),
#  ('FEITOS', 32),
#  ('DOCE', 31),
#  ('CUJA', 31),
#  ('OUTRA', 31),
#  ('PALAVRAS', 31),
#  ('ISTO', 31),
#  ('NAUS', 31),
#  ('FOGO', 31),
#  ('COSTA', 30),
#  ('ALTO', 30),
#  ('CO', 30),
#  ('DONDE', 30),
#  ('PELAS', 30),
#  ('VENTO', 30),
#  ('NESTE', 30),
#  ('VÊM', 30),
#  ('SERÁ', 30),
#  ('ESFORÇO', 30),
#  ('INDA', 29),
#  ('DELE', 29),
#  ('GAMA', 29),
#  ('ALGUM', 29),
#  ('TÊM', 29),
#  ('ENQUANTO', 28),
#  ('SANGUE', 28),
#  ('VÁRIAS', 28),
#  ('FORA', 28),
#  ('DURO', 28),
#  ('DESTE', 28),
#  ('TU', 27),
#  ('AINDA', 27),
#  ('SOL', 27),
#  ('NUM', 27),
#  ('ANTES', 27),
#  ('AQUELE', 27),
#  ('IS', 27),
#  ('LEI', 27),
#  ('ELECTRONIC', 27),
#  ('FORAM', 27),
#  ('CAMPO', 27),
#  ('SEGUNDO', 27),
#  ('GESTO', 27),
#  ('PÁTRIA', 27),
#  ('"NÃO', 26),
#  ('GLÓRIA', 26),
#  ('DÁ', 26),
#  ('PRIMEIRO', 26),
#  ('PELOS', 26),
#  ('CERTO', 26),
#  ('VEZES', 26),
#  ('TANTA', 26),
#  ('SENDO', 25),
#  ('ELA', 25),
#  ('MUI', 25),
#  ('E,', 25),
#  ('DUM', 25),
#  ('ATÉ', 24),
#  ('GUTENBERG', 24),
#  ('LUZ', 24),
#  ('ESTAS', 24),
#  ('FAZER', 24),
#  ('ARTE', 24),
#  ('VÓS,', 24),
#  ('NOVO', 24),
#  ('GUERRA', 23),
#  ('GRÃO', 23),
#  ('NÓS', 23),
#  ('OBRAS', 23),
#  ('VOZ', 23),
#  ('VENTOS', 23),
#  ('TEU', 23),
#  ('JUNTO', 23),
#  ('PARTES', 22),
#  ('SANTA', 22),
#  ('CAMINHO', 22),
#  ('OLHA', 22),
#  ('ESTES', 22),
#  ('MAS,', 22),
#  ('ENTÃO', 22),
#  ('DIANTE', 22),
#  ('DURA', 22),
#  ('MUITOS', 22),
#  ('SUAS', 22),
#  ('DEUSES', 22),
#  ('WORKS', 22),
#  ('BY', 22),
#  ('CORPO', 21),
#  ('TRABALHOS', 21),
#  ("CO'OS", 21),
#  ('REIS', 21),
#  ('MARES', 21),
#  ('MÃO', 21),
#  ('FIM', 21),
#  ('FORMOSA', 21),
#  ('TERMS', 21),
#  ('TRAZ', 21),
#  ('COR', 21),
#  ('FILHOS', 21),
#  ('NOT', 21),
#  ('LARGO', 21),
#  ('"OLHA', 21),
#  ('DIA', 21),
#  ('POSTO', 21),
#  ('AR', 20),
#  ('CUJO', 20),
#  ('IR', 20),
#  ('TI', 20),
#  ('CAMPOS', 20),
#  ('QUIS', 20),
#  ('TANTAS', 20),
#  ('SOMENTE', 20),
#  ('OURO', 20),
#  ('CAPITÃO,', 20),
#  ('VOSSO', 20),
#  ('VÊS', 20),
#  ('TANTOS', 19),
#  ('LONGO', 19),
#  ('VÁRIOS', 19),
#  ('ÍNDIA', 19),
#  ('VEREIS', 19),
#  ('ALTOS', 19),
#  ('UNS', 19),
#  ('TEMOR', 19),
#  ('ENFIM,', 19),
#  ('CORAÇÃO', 19),
#  ('BE', 19),
#  ('TAIS', 19),
#  ('PORTO', 19),
#  ('ARE', 19),
#  ('QUASE', 19),
#  ('VIU', 19),
#  ('COA', 19),
#  ('ERAM', 19),
#  ('IF', 19),
#  ('NOVA', 19),
#  ('FAZEM', 19),
#  ('FARÁ', 19),
#  ('TEJO', 18),
#  ('MOSTRA', 18),
#  ('RIO', 18),
#  ('MAIS,', 18),
#  ('MONTES', 18),
#  ('PEITOS', 18),
#  ('DANDO', 18),
#  ('SABE', 18),
#  ('MÃOS', 18),
#  ('PARECE', 18),
#  ('LÁGRIMAS', 18),
#  ('BUSCAR', 18),
#  ('ALGUNS', 18),
#  ('PARTE,', 18),
#  ('GENTIO', 18),
#  ('BRAÇO', 18),
#  ('ARMADA', 18),
#  ('ALL', 18),
#  ('CANTO', 18),
#  ('MEUS', 17),
#  ('FAZENDO', 17),
#  ('TODAS', 17),
#  ('MEU', 17),
#  ('FORTUNA', 17),
#  ('ELES', 17),
#  ('POUCA', 17),
#  ('SANTO', 17),
#  ('CASO', 17),
#  ('FERRO', 17),
#  ('ROSTO', 17),
#  ('PORÉM', 17),
#  ('FORÇAS', 17),
#  ('NESTA', 17),
#  ('FORTES', 17),
#  ('CADA', 17),
#  ('LEVA', 17),
#  ('TRABALHO', 17),
#  ('GRÃ', 17),
#  ('ANTIGO', 17),
#  ('TENS', 17),
#  ('INIMIGOS', 17),
#  ('CLARA', 16),
#  ('PADRE', 16),
#  ('NOVAS', 16),
#  ('MÃE', 16),
#  ('DEUSA', 16),
#  ('QUER', 16),
#  ('ARDENTE,', 16),
#  ('LEVE', 16),
#  ('FERO', 16),
#  ('NELA', 16),
#  ('MUNDO,', 16),
#  ('ESTRANHA', 16),
#  ('ORA', 16),
#  ('VOSSOS', 16),
#  ('DOIS', 16),
#  ('NOITE', 15),
#  ('THAT', 15),
#  ('MINHA', 15),
#  ('TOMAR', 15),
#  ('DOM', 15),
#  ('HUMANO', 15),
#  ('MOURO,', 15),
#  ('SOBERBA', 15),
#  ('MAY', 15),
#  ('PAI', 15),
#  ('MEDO', 15),
#  ('COMPANHIA', 15),
#  ('QUALQUER', 15),
#  ('PEITO,', 15),
#  ('CÉUS', 15),
#  ('RICA', 15),
#  ('TRÊS', 15),
#  ('ANTIGA', 15),
#  ('VIL', 15),
#  ('GAMA,', 15),
#  ('AT', 15),
#  ('FIRME', 15),
#  ('CRISTO', 15),
#  ('"JÁ', 15),
#  ('VELHO', 15),
#  ('TEVE', 15),
#  ('FOSSE', 15),
#  ('SOBERBO', 15),
#  ('BACO', 15),
#  ('FALSO', 15),
#  ('SUBLIME', 15),
#  ('VIR', 15),
#  ('TRISTE', 14),
#  ('DIZ', 14),
#  ('SINAL', 14),
#  ('SENÃO', 14),
#  ('FROTA', 14),
#  ('SEJA', 14),
#  ('RAZÃO', 14),
#  ('GENTE.', 14),
#  ('DEIXA', 14),
#  ('ARDENTE', 14),
#  ('LARGA', 14),
#  ('VOSSA', 14),
#  ('FROM', 14),
#  ('DÃO', 14),
#  ('DONATIONS', 14),
#  ('CÉU,', 14),
#  ('FOUNDATION', 14),
#  ('TORNA', 14),
#  ('SÓS', 14),
#  ('OTHER', 14),
#  ('DESEJO', 14),
#  ('DAQUI', 14),
#  ('CABO', 14),
#  ('NINFAS', 13),
#  ('COPYRIGHT', 13),
#  ('DISSE', 13),
#  ('NISTO', 13),
#  ('SORTE', 13),
#  ('FAVOR', 13),
#  ('GUERRA,', 13),
#  ('ARCHIVE', 13),
#  ('DIVINA', 13),
#  ('AFONSO', 13),
#  ('REINOS', 13),
#  ('ETERNA', 13),
#  ('EXÉRCITO', 13),
#  ('VIRTUDE', 13),
#  ('MEMÓRIA', 13),
#  ('VELAS', 13),
#  ('DESPOIS', 13),
#  ('DEIXANDO', 13),
#  ('USE', 13),
#  ('VITÓRIA', 13),
#  ('LITERARY', 13),
#  ('FULL', 13),
#  ('FERA', 13),
#  ('MANEIRA', 13),
#  ('DIA,', 13),
#  ('MOÇO', 13),
#  ('FICA', 13),
#  ('DISSE,', 13),
#  ('MUITAS', 13),
#  ('ARMADA,', 13),
#  ('PÔR', 13),
#  ('CABEÇA', 13),
#  ('VALOR', 13),
#  ('TERRENO', 13),
#  ('FALTA', 13),
#  ('MONTE', 13),
#  ('DESTES', 13),
#  ('NOVOS', 13),
#  ('LEDO', 13),
#  ('NOSSOS', 12),
#  ('MUROS', 12),
#  ('PILOTO', 12),
#  ('TANTO,', 12),
#  ('DEUS,', 12),
#  ('FORÇA,', 12),
#  ('LUSO', 12),
#  ('"A', 12),
#  ('CAVALEIRO,', 12),
#  ('INDO', 12),
#  ('SÚBITO', 12),
#  ('PORTUGUÊS', 12),
#  ('COUSAS', 12),
#  ('ESTAR', 12),
#  ('AFONSO,', 12),
#  ('IT', 12),
#  ('ENGANO', 12),
#  ('JUGO', 12),
#  ('POUCOS', 12),
#  ('AQUELES', 12),
#  ('PERIGOS', 12),
#  ('3', 12),
#  ('BELA', 12),
#  ('GUERRAS', 12),
#  ('FUROR', 12),
#  ('NAU', 12),
#  ('CASA', 12),
#  ('LUSITANO,', 12),
#  ('IRA', 12),
#  ('CORTANDO', 12),
#  ('"EIS', 12),
#  ('CASOS', 12),
#  ('"Ó', 12),
#  ('MELHOR', 12),
#  ('PASSAR', 12),
#  ('FÚRIA', 12),
#  ('F', 12),
#  ('VÉNUS', 12),
#  ('FORTE,', 12),
#  ('CONSIGO', 12),
#  ('ESTE,', 12),
#  ('BRAVO', 12),
#  ('QUAIS', 12),
#  ('VENTURA', 12),
#  ('ANDAVA', 12),
#  ('INIMIGO', 12),
#  ('CÁ', 12),
#  ('SOL,', 12),
#  ('ESCURA', 12),
#  ('FILHO,', 12),
#  ('BÁRBARO', 11),
#  ('ESPERANÇA', 11),
#  ('ÁFRICA', 11),
#  ('MAIOR', 11),
#  ('VINHA', 11),
#  ('4', 11),
#  ('LICENSE', 11),
#  ('BRAÇOS', 11),
#  ('PARAGRAPH', 11),
#  ('PAZ', 11),
#  ('SABER', 11),
#  ('AQUELA', 11),
#  ('ON', 11),
#  ('"COM', 11),
#  ('ESTRELAS', 11),
#  ('TERÁ', 11),
#  ('MEIO', 11),
#  ('30', 11),
#  ('FRACO', 11),
#  ('PORQUE,', 11),
#  ('VONTADE', 11),
#  ('NEGRO', 11),
#  ('ALTAS', 11),
#  ('CIMA', 11),
#  ('PASSA', 11),
#  ('CAUSA', 11),
#  ('SETAS', 11),
#  ('60', 11),
#  ('SENHOR', 11),
#  ('ENGENHO', 11),
#  ('LANÇA', 11),
#  ('É,', 11),
#  ('ASSI', 11),
#  ('PÕE', 11),
#  ('NADA', 11),
#  ('ALEGRE', 11),
#  ('90', 11),
#  ('TEUS', 11),
#  ('ANTIGOS', 11),
#  ('SONO', 11),
#  ('VIDA,', 11),
#  ('50', 11),
#  ('NELE', 11),
#  ('22', 11),
#  ('COUSA', 11),
#  ('BATÉIS', 11),
#  ('PÓLO', 11),
#  ('NOBRES', 11),
#  ('PRAIAS', 11),
#  ('PORTUGUESES', 11),
#  ('PRÉMIO', 11),
#  ('IMPÉRIO', 11),
#  ('VERDADE,', 11),
#  ('ISSO', 11),
#  ('FRIO', 11),
#  ('FILHA', 11),
#  ('TAMBÉM,', 11),
#  ('DOUS', 11),
#  ('48', 10),
#  ('79', 10),
#  ('ENTRA', 10),
#  ('41', 10),
#  ('12', 10),
#  ('34', 10),
#  ('9', 10),
#  ('59', 10),
#  ('LEIS', 10),
#  ('DELES', 10),
#  ('46', 10),
#  ('65', 10),
#  ('61', 10),
#  ('SEGURO', 10),
#  ('23', 10),
#  ('6', 10),
#  ('FAMOSO', 10),
#  ('MÁ', 10),
#  ('40', 10),
#  ('GERAÇÃO', 10),
#  ('63', 10),
#  ('CAN', 10),
#  ('ANOS', 10),
#  ('58', 10),
#  ('DAQUELA', 10),
#  ('FADO', 10),
#  ('26', 10),
#  ('80', 10),
#  ('81', 10),
#  ('VIA', 10),
#  ('FUNDO', 10),
#  ('66', 10),
#  ('COLO', 10),
#  ('29', 10),
#  ('JUSTA', 10),
#  ('NINGUÉM', 10),
#  ('MORTOS', 10),
#  ('31', 10),
#  ('LUSITANO', 10),
#  ('56', 10),
#  ('ÂNIMO', 10),
#  ('BOM', 10),
#  ('SÁBIO', 10),
#  ('17', 10),
#  ('70', 10),
#  ('"QUE', 10),
#  ('24', 10),
#  ('38', 10),
#  ('54', 10),
#  ('VENTO,', 10),
#  ('DANO,', 10),
#  ('ENGANO,', 10),
#  ('82', 10),
#  ('5', 10),
#  ('73', 10),
#  ('PRIMEIRA', 10),
#  ('7', 10),
#  ('53', 10),
#  ('DOZE', 10),
#  ('TUA', 10),
#  ('HOMENS', 10),
#  ('43', 10),
#  ('DESSE', 10),
#  ('77', 10),
#  ('78', 10),
#  ('ACCESS', 10),
#  ('VERDADE', 10),
#  ('52', 10),
#  ('45', 10),
#  ('FRONTE', 10),
#  ('44', 10),
#  ('71', 10),
#  ('13', 10),
#  ('DEBAIXO', 10),
#  ('ELE,', 10),
#  ('COS', 10),
#  ('UNITED', 10),
#  ('68', 10),
#  ('BUSCANDO', 10),
#  ('39', 10),
#  ('19', 10),
#  ('57', 10),
#  ('86', 10),
#  ('SOIS', 10),
#  ('11', 10),
#  ('51', 10),
#  ('62', 10),
#  ('75', 10),
#  ('JUÍZO', 10),
#  ('83', 10),
#  ('85', 10),
#  ('84', 10),
#  ('8', 10),
#  ('74', 10),
#  ('64', 10),
#  ('CIDADES', 10),
#  ('25', 10),
#  ('49', 10),
#  ('ALMAS', 10),
#  ('15', 10),
#  ('28', 10),
#  ('18', 10),
#  ('36', 10),
#  ('27', 10),
#  ('47', 10),
#  ('PERIGO', 10),
#  ('72', 10),
#  ('NAUS,', 10),
#  ('42', 10),
#  ('16', 10),
#  ('1', 10),
#  ('32', 10),
#  ('TORPE', 10),
#  ('69', 10),
#  ('10', 10),
#  ('VÊ,', 10),
#  ('87', 10),
#  ('35', 10),
#  ('DAMAS', 10),
#  ('LONGOS', 10),
#  ('IRADO,', 10),
#  ('2', 10),
#  ('37', 10),
#  ('20', 10),
#  ('55', 10),
#  ('76', 10),
#  ('33', 10),
#  ('ÍNDIA,', 10),
#  ('NOSSA', 10),
#  ('CONSELHO', 10),
#  ('67', 10),
#  ('RAIOS', 10),
#  ('14', 10),
#  ('PÔS', 10),
#  ('REMÉDIO', 9),
#  ('TODOS,', 9),
#  ('PASSO', 9),
#  ('FAMOSA', 9),
#  ('PRÍNCIPE', 9),
#  ('FROTA,', 9),
#  ('NOSSO', 9),
#  ('ESTANDO', 9),
#  ('POSSA', 9),
#  ('HUMANA', 9),
#  ('ILUSTRES', 9),
#  ('NÃO,', 9),
#  ('DEU', 9),
#  ('TAMANHO', 9),
#  ('HONRAS', 9),
#  ('TOMOU', 9),
#  ('PUBLIC', 9),
#  ('VITÓRIAS', 9),
#  ('FORA,', 9),
#  ('95', 9),
#  ('PERTO', 9),
#  ('PURO', 9),
#  ('GRANDE,', 9),
#  ('AONDE', 9),
#  ('SERRA', 9),
#  ('PROFUNDO,', 9),
#  ('DUROS', 9),
#  ('REINO,', 9),
#  ('OCEANO,', 9),
#  ('VEIO', 9),
#  ('PRESA', 9),
#  ('RAZÕES', 9),
#  ('WE', 9),
#  ('PRAIA', 9),
#  ('ESTAVAM', 9),
#  ('AGREEMENT', 9),
#  ('FICOU', 9),
#  ('SÓ,', 9),
#  ('EIS', 9),
#  ('DIZ-LHE', 9),
#  ('PAI,', 9),
#  ('TENDO', 9),
#  ('ESPADA', 9),
#  ('FEITO', 9),
#  ('CORRENDO', 9),
#  ('AGREE', 9),
#  ('ASSENTO', 9),
#  ('94', 9),
#  ('COR,', 9),
#  ('AQUI,', 9),
#  ('SUA,', 9),
#  ('FRACA', 9),
#  ('JÚPITER', 9),
#  ('VÃO,', 9),
#  ('91', 9),
#  ('ALMA', 9),
#  ('EBOOK', 9),
#  ('MANCEBO', 9),
#  ('FAMA,', 9),
#  ('QUANTOS', 9),
#  ('LONGA', 9),
#  ('LUSITANA,', 9),
#  ('21', 9),
#  ('89', 9),
#  ('YOUR', 9),
#  ('88', 9),
#  ('PREÇO', 9),
#  ('COISAS', 9),
#  ('MODO', 9),
#  ('DEUSES,', 9),
#  ('BELA,', 9),
#  ('TENHO', 9),
#  ('AJUDA', 9),
#  ('AVANTE', 9),
#  ('ANIMAIS', 9),
#  ('GRANDES,', 9),
#  ('RICO', 9),
#  ('LÍNGUA', 9),
#  ('MAURA', 9),
#  ('93', 9),
#  ('HUMANO,', 9),
#  ('CHAMA', 9),
#  ('PERIGOS,', 9),
#  ('LINDA', 9),
#  ('"SE', 9),
#  ('ALGUMA', 9),
#  ('CIDADE,', 9),
#  ('MUST', 9),
#  ('ARMAS,', 9),
#  ('SERENO', 9),
#  ('COMEÇA', 9),
#  ('MANHA', 9),
#  ('ESPÍRITO', 9),
#  ('FÉ', 9),
#  ('92', 9),
#  ('SOM', 9),
#  ('USADO', 9),
#  ('MORTE,', 9),
#  ('ALEGRIA,', 8),
#  ('DESEJADA', 8),
#  ('DOMAIN', 8),
#  ('COPY', 8),
#  ('POSTA', 8),
#  ('WITHOUT', 8),
#  ('MOSTRAS', 8),
#  ('ÁSPEROS', 8),
#  ('98', 8),
#  ('ABOUT', 8),
#  ('MARTE', 8),
#  ('PODER,', 8),
#  ('"QUAL', 8),
#  ('CULPA', 8),
#  ('VIRÁ', 8),
#  ('AMA,', 8),
#  ('LEDA', 8),
#  ('OURO,', 8),
#  ('"O', 8),
#  ('AJUNTA', 8),
#  ('RAMO', 8),
#  ('RESPONDE', 8),
#  ('OBRIGA', 8),
#  ('PALMA', 8),
#  ('IDADE,', 8),
#  ('CORES', 8),
#  ('SUBTIL', 8),
#  ('ARTE,', 8),
#  ('VERSOS', 8),
#  ('ETERNO', 8),
#  ('PENSAMENTO', 8),
#  ('GOLPES', 8),
#  ('BOCA', 8),
#  ('VINGANÇA', 8),
#  ('COBIÇA', 8),
#  ('NEGRA', 8),
#  ('VENCER', 8),
#  ('99', 8),
#  ('SET', 8),
#  ('POVOS', 8),
#  ('DALI', 8),
#  ('PESO', 8),
#  ('ANDA', 8),
#  ('DENTRO', 8),
#  ('TRAZIA', 8),
#  ('"ESTE', 8),
#  ('VEJA', 8),
#  ('NUMA', 8),
#  ('FEE', 8),
#  ('VOSSAS', 8),
#  ('FEROS', 8),
#  ('USANÇA', 8),
#  ('SUSTENTAR', 8),
#  ('NOMES', 8),
#  ('INIMIGA', 8),
#  ('ESPERA', 8),
#  ('FAZENDA', 8),
#  ('JUSTO', 8),
#  ('96', 8),
#  ('JEITO', 8),
#  ('OCEANO', 8),
#  ('PROA', 8),
#  ('HORRENDO', 8),
#  ("C'UM", 8),
#  ('MEMBROS', 8),
#  ('"ESTA', 8),
#  ('(QUE', 8),
#  ('VINHAM', 8),
#  ('VENCEDOR', 8),
#  ('ALEGRES', 8),
#  ('DIVERSOS', 8),
#  ('MULTIDÃO', 8),
#  ('DOUTRA', 8),
#  ('PÉS', 8),
#  ('BRANCA', 8),
#  ('INCLUDING', 8),
#  ('--"Ó', 8),
#  ('LOUVOR', 8),
#  ('ILHA,', 8),
#  ('AVES', 8),
#  ('ILUSTRE,', 8),
#  ('LEVANDO', 8),
#  ('NAQUELE', 8),
#  ('CARNE', 8),
#  ('NINFA', 8),
#  ('MESTRE', 8),
#  ('DIZEM', 8),
#  ('NATURA', 8),
#  ('FOGO,', 8),
#  ('NAÇÕES', 8),
#  ('DIZENDO,', 8),
#  ('MESMO', 8),
#  ('FONTE', 8),
#  ('FILHAS', 8),
#  ('STATES', 8),
#  ('FRIO,', 8),
#  ('ESTREITO', 8),
#  ('FORTH', 8),
#  ('DIZENDO', 8),
#  ('ILHAS', 8),
#  ('EUROPA', 8),
#  ('SEI', 8),
#  ('VIA,', 8),
#  ('OLIMPO', 8),
#  ('CRUEL', 8),
#  ('FOGE', 8),
#  ('ELAS', 8),
#  ('AMOR,', 8),
#  ('HÁ-DE', 8),
#  ('BANDA', 8),
#  ('LUSITANOS', 8),
#  ('"ASSIM', 8),
#  ('SAIR', 8),
#  ('RIO,', 8),
#  ('CORRE', 8),
#  ('97', 8),
#  ('NELAS', 8),
#  ('VI', 8),
#  ('TEMPO,', 8),
#  ('JUNTAMENTE,', 8),
#  ('ESTÁ,', 7),
#  ('CONTA', 7),
#  ('TAIS,', 7),
#  ('MATA', 7),
#  ('BATEL', 7),
#  ('WILL', 7),
#  ('AURORA', 7),
#  ('AQUILO', 7),
#  ('PRÓPRIOS', 7),
#  ('PRÓPRIO', 7),
#  ('DUAS', 7),
#  ('BRUTO', 7),
#  ('CASTELHANO,', 7),
#  ('ORIENTE,', 7),
#  ('AQUELAS', 7),
#  ('DOURO', 7),
#  ('BRUTA', 7),
#  ('SECTION', 7),
#  ('INIMIGOS,', 7),
#  ('ANGÉLICA', 7),
#  ('SOMBRA', 7),
#  ('ENTRANHAS', 7),
#  ('VENTURA,', 7),
#  ('CANTANDO', 7),
#  ('TRATO', 7),
#  ('LOGO,', 7),
#  ('SENHORIO', 7),
#  ('SERVIÇO', 7),
#  ('SEJAM', 7),
#  ('WHICH', 7),
#  ('CONDE', 7),
#  ('AMBOS', 7),
#  ('AJUNTAMENTO', 7),
#  ('CUIDA', 7),
#  ('FARÃO', 7),
#  ('PIEDADE', 7),
#  ('SUMA', 7),
#  ('ASSOCIATED', 7),
#  ('FORMA', 7),
#  ('CINCO', 7),
#  ('ESTAVA,', 7),
#  ('CAVALOS', 7),
#  ('OUTREM', 7),
#  ('PAÇOS', 7),
#  ('BELO', 7),
#  ('-', 7),
#  ('VERÁ', 7),
#  ('PORTAS', 7),
#  ('GENTES,', 7),
#  ('MIM', 7),
#  ('LAWS', 7),
#  ('FALA', 7),
#  ('JUSTIÇA', 7),
#  ('POVO,', 7),
#  ('FICAVA', 7),
#  ('BREVE', 7),
#  ('SUAVE', 7),
#  ('NOUTRA', 7),
#  ('TODA,', 7),
#  ('PORTUGUESA', 7),
#  ('NINFAS,', 7),
#  ('ESTOUTRO', 7),
#  ('ASAS', 7),
#  ('DAQUELES', 7),
#  ('FLAMAS', 7),
#  ('MURO', 7),
#  ('GENTE;', 7),
#  ('CARRO', 7),
#  ('CATUAL', 7),
#  ('IRADO', 7),
#  ('FEBO', 7),
#  ('DIAS', 7),
#  ('DELA.', 7),
#  ('AMADA', 7),
#  ('WORK,', 7),
#  ...]

# %%
# ?string.strip
# Out:
# Object `string.strip` not found.
